# %%
import numpy as np
import scipy.signal
from scipy.io import wavfile
import scipy.io.wavfile
import librosa
import matplotlib.pyplot as plt
import os
from pandas import DataFrame
import time
from scipy.signal.windows import hamming
from sklearn.cluster import KMeans

# %%
# Lấy list wav files từ 1 folder
def get_wav_files(folder_path):
    wav_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".wav"):
                wav_files.append(os.path.join(root, file))
    return wav_files

base_audio_train_folder = "NguyenAmHuanLuyen-16k"
audio_train_folders = [os.path.join(base_audio_train_folder, folder) for folder in os.listdir(base_audio_train_folder)]
audio_train_file_paths = []
for folder in audio_train_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_train_file_paths.append(item)

base_audio_test_folder = "NguyenAmKiemThu-16k"
audio_test_folders = [os.path.join(base_audio_test_folder, folder) for folder in os.listdir(base_audio_test_folder)]
audio_test_file_paths = []
for folder in audio_test_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_test_file_paths.append(item)

# %%
def find_vowel_files(audio_file_paths, vowel_file):
    vowel_files_in_paths = []
    for item in audio_file_paths:
        # Tìm các file trong list tương ứng của từng folder
        matching_files = [f for f in item['audio_files'] if os.path.basename(f) in vowel_file]
        if matching_files:
            vowel_files_in_paths.extend(matching_files)
    return vowel_files_in_paths

# %%
def format_accuracy_matrix(matrix):
    formatted_matrix = matrix.copy()
    for i in range(1, matrix.shape[0]):
        for j in range(1, matrix.shape[1]):
            # Chỉ format các ô không phải tiêu đề (giả định đây là số hoặc None)
            if matrix[i, j] is not None:
                formatted_matrix[i, j] = f"{matrix[i, j]:.1f}"
    return formatted_matrix

# %%
def show_accuracy_matrix(accuracy_percent_synthesis, title):
    formatted = format_accuracy_matrix(accuracy_percent_synthesis)
    fig, ax = plt.subplots(figsize=(8, 3))  # Modify the size as needed
    ax.set_title(title, color='blue', loc='center',fontweight='bold')
    ax.axis('off')
    ax.axis('tight')
    table = ax.table(cellText=formatted, loc='center', cellLoc='center', edges='closed')
    table.auto_set_column_width(col=list(range(len(formatted[0]))))  
    table.auto_set_font_size(False)  
    table.set_fontsize(11)  
    fig.tight_layout()
    plt.show()

# %%
def show_statictics_table(statictics_table, title):
    # Vẽ bảng thống kê
    fig, ax = plt.subplots()
    ax.set_title(title)
    ax.axis('off')
    ax.axis('tight')
    ax.table(cellText=statictics_table, loc='center')
    fig.tight_layout()
    plt.show()

# %%
def show_feature_mfcc_vectors(feature_vectors, K, title1):
    N_MFCC = 13
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    n = np.arange(N_MFCC)
    plt.figure(figsize=(20,10))
    plt.title(title1)
    plt.plot(n, feature_vectors[0, :], 'b', label=vowel_files[0])
    plt.plot(n, feature_vectors[K, :], 'y', label=vowel_files[1])
    plt.plot(n, feature_vectors[2 * K, :], 'darkcyan', label=vowel_files[2])
    plt.plot(n, feature_vectors[3 * K, :], 'orange', label=vowel_files[3])
    plt.plot(n, feature_vectors[4 * K, :], 'r', label=vowel_files[4])
    plt.legend()
    plt.xlabel('Chỉ số')
    plt.ylabel('Hệ số MFCC')
    plt.show()
    plt.figure()

# %%
def show_confusion_matrix(confusion_matrix, title, time_processing_vowels):
    for row in confusion_matrix[1:]:
        if type(row[-1]) == float:  
            row[-1] = "{:.1f}".format(row[-1])
        else:
            row[-1] = ""
    df_cm = DataFrame(
        [row[1:] for row in confusion_matrix[1:]], 
        columns=confusion_matrix[0][1:],  
        index=[row[0] for row in confusion_matrix[1:]]  
    )

    avg_time_vowels = [round(item['avg_time'],4) for item in time_processing_vowels]
    avg_time_vowels.append("")
    df_cm['Time-Avg'] = avg_time_vowels
    fig, ax = plt.subplots(figsize=(14, 5))  
    ax.set_title(title, color='blue', loc='center', fontweight='bold')
    ax.axis('off')  
    tab = ax.table(cellText=df_cm.values, cellLoc='center', loc='center', rowLabels=df_cm.index, colLabels=df_cm.columns)
    tab.auto_set_font_size(False)
    tab.set_fontsize(14)
    tab.scale(1, 1.4)
    max_index = df_cm.iloc[:-1, -2].astype(float).idxmax()  # Tìm percent cao nhất
    min_index = df_cm.iloc[:-1, -2].astype(float).idxmin()  # Tìm percent thấp nhất


    for key, cell in tab.get_celld().items():
        if key[0] == 0:
            cell.set_text_props(color='black', fontweight='bold')
            cell.set_facecolor('lightgrey')
            
    for (i, row) in enumerate(df_cm.iterrows(), start=1):
        if row[0] == max_index :  # Highlight dòng có percent cao nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j-1)].set_facecolor('lightgreen')
        if row[0] == min_index:   # Highlight dòng có percent thấp nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j-1)].set_facecolor('salmon')
    
    plt.show()

# %%
def show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime):
    plt.figure()
    plt.plot(np.arange(0, len(data) * T, T), data) # tín hiệu sau khi chuẩn hóa
    plt.title("Speech and Stable Area of the Signal ")
    # Vẽ vùng tiếng nói
    plt.axvline(x=(speech_area[0]) * sample_shift_frame * T, color='r', linestyle='--', label="Start of Speech")
    plt.axvline(x=(speech_area[-1]) * sample_shift_frame * T, color='r', linestyle='--', label="End of Speech")
    # Vẽ vùng ổn định
    plt.axvline(x=(startTime) * sample_shift_frame * T, color='b', linestyle='--', label="Start of Stable Speech")
    plt.axvline(x=(endTime) * sample_shift_frame * T, color='b', linestyle='--', label="End of Stable Speech")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Khoảng cách Euclidean giữa 2 vector
def euclideanDistance(v1, v2):
    return np.linalg.norm(v1 - v2)

# %%
def accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx):
    total_percent = 0
    for i in range(5):
        total_correct = confusion_matrix[i + 1][i + 1] # Số lần nhận dạng đúng
        confusion_matrix[i + 1][6] = f"{total_correct}/21" 
        percent = float(total_correct) / 21 * 100 # Phần trăm nhận dạng đúng
        confusion_matrix[i + 1][7] = percent
        total_percent += percent
    confusion_matrix[6][7] = total_percent / 5
    accuracy_percent_synthesis[1][idx] = total_percent / 5 # Độ chính xác trung bình
    total_percent = 0
    if (idx == 4):
        for i in range(4):
            total_percent += accuracy_percent_synthesis[1][i + 1]
        accuracy_percent_synthesis[1][idx + 1] = total_percent / 4 # Độ chính xác trung bình của tất cả các K
    return confusion_matrix, accuracy_percent_synthesis

# %%
def find_speech_area(files, frame_length, frame_shift):
    sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
    T = 1 / sampleRate # Chu kỳ
    # 1s -> 16K sample
    sample_one_frame = round(frame_length * sampleRate) # số mẫu 1 khung
    sample_shift_frame = round(frame_shift * sampleRate) # số mẫu khoảng dịch
    # Tổng số khung thu được = (số lượng mẫu - số mẫu 1 khung) // số mẫu khoảng dịch + 1
    total_number_frame = (len(data) - sample_one_frame) // sample_shift_frame + 1
    # Chuẩn hóa data về biên độ [-1, 1]
    data = data / abs(max(data))
    # Chia data thành các frame
    list_frames = [data[i * sample_shift_frame : i * sample_shift_frame + sample_one_frame] for i in range(total_number_frame)]
    list_frames = np.array(list_frames)
    ste_frame = np.sum(list_frames ** 2, axis=1) # STE từng frame
    ste_frame /= max(ste_frame) # Chuẩn hóa STE
    threshold = 0.03 # Ngưỡng thủ công
    speech_area = np.where(ste_frame >= threshold)[0] # tìm vùng tiếng nói
    return list_frames, data, T, sample_shift_frame, speech_area

# %%
def find_stable_area(files, frame_length, frame_shift): # tìm vùng ổn định
    list_frames, data, T, sample_shift_frame, speech_area = find_speech_area(files, frame_length, frame_shift)
    dist = int(np.ceil((speech_area[-1] - speech_area[0]) / 3)) # Chia thành 3 đoạn bằng nhau
    startTime = speech_area[0] + dist # Vị trí bắt đầu vùng ổn định
    endTime = speech_area[0] + 2 * dist # Vị trí kết thúc vùng ổn định
    return list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area

# %%
def find_vowel_feature_mfcc_vectors(list_frames, timeStart, timeEnd, N_MFCC, Fs, frame_length, frame_shift):
    coef_mfcc_vectors = []
    frame_length_sample = round(frame_length * Fs)   # Độ dài khung (frame length) chuyển đổi sang mẫu
    hop_length_sample = round(frame_shift * Fs)     # Khoảng dịch khung (frame step) chuyển đổi sang mẫu
    for k in range(timeStart, timeEnd + 1): 
        coef_mfcc_vector = librosa.feature.mfcc(y=list_frames[k, :], sr=16000, n_mfcc=N_MFCC+1, n_fft=frame_length_sample, hop_length=hop_length_sample, 
                                        window='hamming')[1:,]  
        coef_mfcc_vectors.append(coef_mfcc_vector.mean(axis=1))  
    return np.array(coef_mfcc_vectors)

# %%
def recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs):
    N_MFCC = 13
    folder_names = [item['folder_name'] for item in audio_test_file_paths]
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    vowels = ["a", "e", "i", "o", "u"]
    num_folders = len(folder_names)
    num_files = len(vowel_files)
    statictics_table = np.zeros((num_folders + 1, num_files + 1), dtype=object)
    statictics_table[0, 0] = ""
    statictics_table[1:, 0] = folder_names
    statictics_table[0, 1:] = vowel_files
    confusion_matrix = [
        ["", "a", "e", "i", "o", "u", "Tỉ lệ", "ĐCX (%)"],
        ["  a  ", 0, 0, 0, 0, 0, 0, 0],
        ["  e  ", 0, 0, 0, 0, 0, 0, 0],
        ["  i  ", 0, 0, 0, 0, 0, 0, 0],
        ["  o  ", 0, 0, 0, 0, 0, 0, 0],
        ["  u  ", 0, 0, 0, 0, 0, 0, 0],
        ["     ", "", "", "", "", "", "", 0]
    ]

    time_processing_vowels = []
    for i in range(num_files):
        vowel_files_in_paths = find_vowel_files(audio_test_file_paths, vowel_files[i])
        j = -1
        time_processing_vowel = 0
        for file in vowel_files_in_paths:
            start_time = time.time()

            j += 1
            # Tìm vùng ổn định
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(file, frame_length, frame_shift)
            # Tìm vector đặc trưng MFCC
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            # Tìm khoảng cách ngắn nhất
            min_dist = euclideanDistance(kmean_mfcc_feature_vectors[0, :], vowel_feature_mfcc_vector)
            index = 0
            for k in range(1, 5 * K): 
                min_t = euclideanDistance(kmean_mfcc_feature_vectors[k, :], vowel_feature_mfcc_vector)
                if min_t < min_dist:
                    min_dist = min_t
                    index = k
            index = index // K            
            # Điền vào bảng
            statictics_table[j + 1, i + 1] = vowels[index]
            confusion_matrix[i + 1][index + 1] += 1

            end_time = time.time()
            time_processing_vowel += (end_time - start_time)

            print(f"Consuming time for {vowels[index]} in {file}: {end_time - start_time}\n")
        avg_time_processing_vowel = time_processing_vowel /len(vowel_files_in_paths)
        vowel_label = file.split('.wav')[0]
        print("label:",vowel_label)
        item = {
            'vowel':vowel_label[-1],
            'avg_time': avg_time_processing_vowel
        }
        time_processing_vowels.append(item)
    print("time consuming vowel:", time_processing_vowels)
    return statictics_table, confusion_matrix, time_processing_vowels

# %%
def find_kmean_vectors(frame_length, frame_shift, Fs, K):
    N_MFCC = 13 # Số lượng hệ số MFCC
    kmean_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC khi áp dụng Kmean
    vowel_file = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] # file nguyên âm
    for i in range(len(vowel_file)): # Chạy từng nguyên âm
        vowel_files_in_paths = find_vowel_files(audio_train_file_paths, vowel_file[i]) # Lấy đường dẫn có vowel_file
        vowel_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC của 1 nguyên âm nhiều người nói
        for files in vowel_files_in_paths: # Duyệt từng file 
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(files, frame_length, frame_shift) # Tìm vùng ổn định
            # Tìm vector đặc trưng MFCC 1 nguyên âm 1 người nói
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            vowel_feature_mfcc_vectors = np.vstack((vowel_feature_mfcc_vectors, vowel_feature_mfcc_vector))
        # Tiến hành chia cụm
        kmeans = KMeans(n_clusters=K, random_state=0).fit(vowel_feature_mfcc_vectors)
        centroids = kmeans.cluster_centers_ # Tìm trung tâm cụm
        kmean_feature_mfcc_vectors = np.vstack((kmean_feature_mfcc_vectors, centroids))
    return kmean_feature_mfcc_vectors # 5 * K vector kmean

# %%
def Bai3():
    frame_length = 0.03 # Độ dài khung
    frame_shift = 0.015 # Độ dịch khung
    Fs = 16000
    # Vẽ 1 tín hiệu từ file để kiểm tra vùng ổn định
    list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area("NguyenAmHuanLuyen-16k/23MTL/i.wav", frame_length, frame_shift)
    show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime)
    accuracy_percent_synthesis = np.zeros((2, 6), dtype=object)
    K_arr = ["K = 2", "K = 3", "K = 4", "K = 5", "ĐCXTB (%)"]
    N_arr = ["N_MFCC = 13"]
    accuracy_percent_synthesis[0, 0] = ""
    accuracy_percent_synthesis[1:, 0] = N_arr
    accuracy_percent_synthesis[0, 1:] = K_arr
    idx = 0
    for K in range(2, 6): # K chạy từ 2 -> 5
        kmean_mfcc_feature_vectors = find_kmean_vectors(frame_length, frame_shift, Fs, K) # Tìm 5 * K vector đặc trưng
        
        statictics_table, confusion_matrix, time_processing_vowels = recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs)
        idx += 1
        confusion_matrix, accuracy_percent_synthesis = accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx)
        # Tiến hành hiển thị vector đặc trưng
        title = f"Vector đặc trưng MFCC với N_MFCC = 13 và K = {K}"
        show_feature_mfcc_vectors(kmean_mfcc_feature_vectors, K, title)
        # In ra bảng thống kê
        title = f"Kết quả nhận dạng với N_MFCC = 13 và K = {K}"
        show_statictics_table(statictics_table, title)
        title = f"Ma trận nhầm lẫn với N_MFCC = 13 và K = {K}"
        show_confusion_matrix(confusion_matrix, title, time_processing_vowels)
        title = f"Độ chính xác nhận dạng tổng hợp theo số cụm K"
    show_accuracy_matrix(accuracy_percent_synthesis, title)

# %%
if __name__ == "__main__":
    Bai3()
# Out:
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.02888202667236328
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.042348623275756836
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.037628173828125
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.03368115425109863
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.035115957260131836
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03343391418457031
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.03529810905456543
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.01899433135986328
#
# Consuming time for a in NguyenAmKiemThu-16k/12FTD/a.wav: 0.022912025451660156
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.029978036880493164
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.033982038497924805
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.019044876098632812
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.022265195846557617
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.0334620475769043
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.03840184211730957
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.033132076263427734
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.03049612045288086
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.018330097198486328
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.023841142654418945
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.027166366577148438
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.02528214454650879
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.019752979278564453
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.02821207046508789
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.027730941772460938
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.023340940475463867
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.022980690002441406
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.022544145584106445
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.026373863220214844
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.017722129821777344
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.02680492401123047
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.03252363204956055
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/e.wav: 0.039832115173339844
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.017442941665649414
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.02648186683654785
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.0351259708404541
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.048935890197753906
#
# Consuming time for e in NguyenAmKiemThu-16k/04MHB/e.wav: 0.039402008056640625
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.04289889335632324
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.021523237228393555
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/e.wav: 0.018913984298706055
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/e.wav: 0.04040408134460449
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/e.wav: 0.02523016929626465
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.02130413055419922
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.026997089385986328
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.026112079620361328
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.03165316581726074
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.02214789390563965
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.024700164794921875
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.029643774032592773
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.024116992950439453
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.041082143783569336
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.04399394989013672
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.07119274139404297
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.032138824462890625
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.03408479690551758
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.04067206382751465
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.03947591781616211
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.03531074523925781
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.04058074951171875
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.03403282165527344
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/i.wav: 0.06631684303283691
#
# Consuming time for i in NguyenAmKiemThu-16k/02FVA/i.wav: 0.06385636329650879
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.05342411994934082
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.05474996566772461
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.037995100021362305
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.023218154907226562
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.022957801818847656
#
# Consuming time for o in NguyenAmKiemThu-16k/11MVD/o.wav: 0.028244972229003906
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.024271011352539062
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.031161785125732422
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.023888826370239258
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.042160987854003906
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.03935503959655762
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.031025171279907227
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.02419590950012207
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/o.wav: 0.0168001651763916
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.03961801528930664
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.03137779235839844
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.032675981521606445
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.03501582145690918
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.0351712703704834
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.029740095138549805
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.036103010177612305
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.02787303924560547
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.018356800079345703
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.029591083526611328
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/u.wav: 0.057550907135009766
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.019271135330200195
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.0208280086517334
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.022076845169067383
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/u.wav: 0.024250268936157227
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.019371986389160156
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.024972200393676758
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.022363901138305664
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.024379730224609375
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.016103267669677734
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.02661585807800293
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.03106999397277832
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.043112993240356445
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.03541302680969238
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.027101993560791016
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.016782283782958984
#
# Consuming time for u in NguyenAmKiemThu-16k/10MSD/u.wav: 0.021040916442871094
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.028722047805786133
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.0325770378112793
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.029698871430896577}, {'vowel': 'e', 'avg_time': 0.02877035595121838}, {'vowel': 'i', 'avg_time': 0.03823035103934152}, {'vowel': 'o', 'avg_time': 0.0317904722122919}, {'vowel': 'u', 'avg_time': 0.02674058505467006}]
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.022516965866088867
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.03224611282348633
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.03502011299133301
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.028475046157836914
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.031236886978149414
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03229093551635742
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.027121782302856445
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.015887022018432617
#
# Consuming time for a in NguyenAmKiemThu-16k/12FTD/a.wav: 0.021540164947509766
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.024498939514160156
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.03112483024597168
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.017634868621826172
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.020185232162475586
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.027228116989135742
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.02423715591430664
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.023751020431518555
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.024757862091064453
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.014424800872802734
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.014536857604980469
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.021663904190063477
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.026656150817871094
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.01741194725036621
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.02390003204345703
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.019565105438232422
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.019491910934448242
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.019801855087280273
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.018594741821289062
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.023014068603515625
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.014503955841064453
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.021764755249023438
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.025897979736328125
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.027599096298217773
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.01409602165222168
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.02144789695739746
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.028862953186035156
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.024858951568603516
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/e.wav: 0.028033018112182617
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.02663898468017578
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.018306970596313477
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/e.wav: 0.015758752822875977
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/e.wav: 0.027231216430664062
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/e.wav: 0.019775867462158203
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.01695990562438965
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.0217132568359375
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.020207881927490234
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.020923137664794922
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.025204896926879883
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.02159881591796875
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.022857189178466797
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.017786741256713867
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.02450704574584961
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.024036169052124023
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.025288105010986328
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.016605854034423828
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.019151926040649414
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.02455878257751465
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.026444196701049805
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.024539947509765625
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.027630090713500977
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.014225006103515625
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/i.wav: 0.014478206634521484
#
# Consuming time for i in NguyenAmKiemThu-16k/02FVA/i.wav: 0.02413320541381836
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/i.wav: 0.01952219009399414
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.016340017318725586
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.022407054901123047
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.02022719383239746
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.017107009887695312
#
# Consuming time for o in NguyenAmKiemThu-16k/11MVD/o.wav: 0.02109384536743164
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.01903390884399414
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.025359153747558594
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.01685810089111328
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.02439117431640625
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.023140907287597656
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.024465084075927734
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.016571044921875
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/o.wav: 0.014187097549438477
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.024282217025756836
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.02571702003479004
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.023408889770507812
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.023669004440307617
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.017238855361938477
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.01866602897644043
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.0257418155670166
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.02013683319091797
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.01435399055480957
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.020446300506591797
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/u.wav: 0.04319906234741211
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.017149925231933594
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.018049001693725586
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.018992185592651367
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/u.wav: 0.021832942962646484
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.016669273376464844
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.023291826248168945
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.02832627296447754
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.023514986038208008
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.01497793197631836
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.01984429359436035
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.05001211166381836
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.0454096794128418
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.02086186408996582
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.02147698402404785
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.014371871948242188
#
# Consuming time for u in NguyenAmKiemThu-16k/10MSD/u.wav: 0.021290063858032227
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.025683879852294922
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.023544788360595703
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.024620703288487027}, {'vowel': 'e', 'avg_time': 0.02174076579865955}, {'vowel': 'i', 'avg_time': 0.02154155004592169}, {'vowel': 'o', 'avg_time': 0.02095439320518857}, {'vowel': 'u', 'avg_time': 0.023966630299886067}]
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.02585601806640625
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.04003190994262695
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.03848433494567871
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.0419619083404541
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.03009200096130371
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03473091125488281
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.043627023696899414
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.015430927276611328
#
# Consuming time for e in NguyenAmKiemThu-16k/12FTD/a.wav: 0.022742033004760742
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.02398991584777832
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.030434846878051758
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.017737388610839844
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.02177262306213379
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.03250384330749512
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.027930021286010742
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.03482508659362793
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.0334169864654541
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.021211862564086914
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.0205838680267334
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.042569875717163086
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.029775142669677734
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.019908905029296875
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.026845932006835938
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.02622079849243164
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.02236199378967285
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.02157425880432129
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.020498037338256836
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.025124788284301758
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.01659107208251953
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.02617812156677246
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.031733036041259766
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.034173011779785156
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.017763137817382812
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.032199859619140625
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.037580013275146484
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.03245282173156738
#
# Consuming time for e in NguyenAmKiemThu-16k/04MHB/e.wav: 0.027187347412109375
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.033833980560302734
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.02031397819519043
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/e.wav: 0.01651597023010254
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/e.wav: 0.0346071720123291
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/e.wav: 0.021580934524536133
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.019619226455688477
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.03032398223876953
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.06493496894836426
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.04109907150268555
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.02060413360595703
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.02621912956237793
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.03163599967956543
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.01914811134338379
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.02570819854736328
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.029001235961914062
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.03531217575073242
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.019335031509399414
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.0263369083404541
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.046416282653808594
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.04071187973022461
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.03626513481140137
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.03374791145324707
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.019708871841430664
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/i.wav: 0.01963210105895996
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/i.wav: 0.029053926467895508
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.022068023681640625
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.02140498161315918
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.026475906372070312
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.024528026580810547
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.020321130752563477
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/o.wav: 0.022105932235717773
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.023150920867919922
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.030658960342407227
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.019782066345214844
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.028609037399291992
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.04117608070373535
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.055886030197143555
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.020472049713134766
#
# Consuming time for o in NguyenAmKiemThu-16k/07FTC/o.wav: 0.017173051834106445
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.03091883659362793
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.030013084411621094
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.03119826316833496
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.02724933624267578
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.022040843963623047
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.02211594581604004
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.026681184768676758
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.02086496353149414
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.018184900283813477
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.02477288246154785
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/u.wav: 0.04910588264465332
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.019050121307373047
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.018726825714111328
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.0216062068939209
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/u.wav: 0.022735118865966797
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.028118133544921875
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.02934885025024414
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.030271053314208984
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.026855945587158203
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.01665472984313965
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.021331071853637695
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.023535728454589844
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.0283050537109375
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.021770954132080078
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.022682905197143555
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.014883995056152344
#
# Consuming time for u in NguyenAmKiemThu-16k/10MSD/u.wav: 0.01913905143737793
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.025949954986572266
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.02406597137451172
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.029986120405651275}, {'vowel': 'e', 'avg_time': 0.025964055742536272}, {'vowel': 'i', 'avg_time': 0.030327728816441128}, {'vowel': 'o', 'avg_time': 0.026801268259684246}, {'vowel': 'u', 'avg_time': 0.02414739699590774}]
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_20892/2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv_2/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.02656722068786621
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.036242008209228516
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.03418111801147461
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.033418893814086914
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.03252577781677246
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03611183166503906
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.03554511070251465
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.02349996566772461
#
# Consuming time for a in NguyenAmKiemThu-16k/12FTD/a.wav: 0.03156685829162598
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.03883004188537598
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.044235944747924805
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.0331268310546875
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.033782005310058594
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.04084515571594238
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.03422093391418457
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.042894840240478516
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.03587675094604492
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.024088144302368164
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.018422842025756836
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.03287982940673828
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.02464771270751953
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.02148914337158203
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.029680967330932617
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.0216829776763916
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.020525217056274414
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.02632308006286621
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.02899003028869629
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.040560007095336914
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.07288002967834473
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.06556487083435059
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.03966116905212402
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.040959835052490234
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.0185086727142334
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.03352212905883789
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.04130911827087402
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.04308676719665527
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/e.wav: 0.03938412666320801
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.04712104797363281
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.03776907920837402
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/e.wav: 0.023263931274414062
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/e.wav: 0.04719400405883789
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/e.wav: 0.023469924926757812
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.021049976348876953
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.02808380126953125
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.026189088821411133
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.02539515495300293
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.02182912826538086
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.02492213249206543
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.029548168182373047
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.02734684944152832
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.031388044357299805
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.028251171112060547
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.04099893569946289
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.04038190841674805
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.03905320167541504
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.04005885124206543
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.043966054916381836
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.030099868774414062
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.037590980529785156
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.019053936004638672
#
# Consuming time for u in NguyenAmKiemThu-16k/10MSD/i.wav: 0.025747060775756836
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/i.wav: 0.03060603141784668
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.028456926345825195
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.0236358642578125
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.028135061264038086
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.027601242065429688
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.02213907241821289
#
# Consuming time for o in NguyenAmKiemThu-16k/11MVD/o.wav: 0.024970054626464844
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.03154611587524414
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.033931732177734375
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.024619102478027344
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.03640604019165039
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.03147697448730469
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.03448891639709473
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.022181987762451172
#
# Consuming time for o in NguyenAmKiemThu-16k/07FTC/o.wav: 0.018212080001831055
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.03174877166748047
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.03500223159790039
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.026784896850585938
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.02916884422302246
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.01953577995300293
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.018340110778808594
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.03501391410827637
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.02332305908203125
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.016072988510131836
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.026402950286865234
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/u.wav: 0.04948711395263672
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.019356966018676758
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.02536797523498535
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.03461313247680664
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/u.wav: 0.038002967834472656
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.026195287704467773
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.03178524971008301
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.024789094924926758
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.029015064239501953
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.018459081649780273
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.021333932876586914
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.023875951766967773
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.025238037109375
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.022395849227905273
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.02230095863342285
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.017740964889526367
#
# Consuming time for u in NguyenAmKiemThu-16k/10MSD/u.wav: 0.01840496063232422
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.02638101577758789
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.024311065673828125
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03302427700587681}, {'vowel': 'e', 'avg_time': 0.036330768040248325}, {'vowel': 'i', 'avg_time': 0.03047701290675572}, {'vowel': 'o', 'avg_time': 0.02753627867925735}, {'vowel': 'u', 'avg_time': 0.025787171863374255}]
