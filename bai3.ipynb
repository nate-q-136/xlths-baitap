# %%
import numpy as np
import scipy.signal
from scipy.io import wavfile
import scipy.io.wavfile
import librosa
import matplotlib.pyplot as plt
import os
from pandas import DataFrame
import time
from scipy.signal.windows import hamming
from sklearn.cluster import KMeans

# %%
# Lấy list wav files từ 1 folder
def get_wav_files(folder_path):
    wav_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".wav"):
                wav_files.append(os.path.join(root, file))
    return wav_files

base_audio_train_folder = "NguyenAmHuanLuyen-16k"
audio_train_folders = [os.path.join(base_audio_train_folder, folder) for folder in os.listdir(base_audio_train_folder)]
audio_train_file_paths = []
for folder in audio_train_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_train_file_paths.append(item)

base_audio_test_folder = "NguyenAmKiemThu-16k"
audio_test_folders = [os.path.join(base_audio_test_folder, folder) for folder in os.listdir(base_audio_test_folder)]
audio_test_file_paths = []
for folder in audio_test_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_test_file_paths.append(item)

# %%
def find_vowel_files(audio_file_paths, vowel_file):
    vowel_files_in_paths = []
    for item in audio_file_paths:
        # Tìm các file trong list tương ứng của từng folder
        matching_files = [f for f in item['audio_files'] if os.path.basename(f) in vowel_file]
        if matching_files:
            vowel_files_in_paths.extend(matching_files)
    return vowel_files_in_paths

# %%
def format_accuracy_matrix(matrix):
    formatted_matrix = matrix.copy()
    for i in range(1, matrix.shape[0]):
        for j in range(1, matrix.shape[1]):
            # Chỉ format các ô không phải tiêu đề (giả định đây là số hoặc None)
            if matrix[i, j] is not None:
                formatted_matrix[i, j] = f"{matrix[i, j]:.1f}"
    return formatted_matrix

# %%
def show_accuracy_matrix(accuracy_percent_synthesis, title):
    formatted = format_accuracy_matrix(accuracy_percent_synthesis)
    fig, ax = plt.subplots(figsize=(8, 3))  # Modify the size as needed
    ax.set_title(title, color='blue', loc='center',fontweight='bold')
    ax.axis('off')
    ax.axis('tight')
    table = ax.table(cellText=formatted, loc='center', cellLoc='center', edges='closed')
    table.auto_set_column_width(col=list(range(len(formatted[0]))))  
    table.auto_set_font_size(False)  
    table.set_fontsize(11)  
    fig.tight_layout()
    plt.show()

# %%
def show_statictics_table(statictics_table, title):
    # Vẽ bảng thống kê
    fig, ax = plt.subplots()
    ax.set_title(title)
    ax.axis('off')
    ax.axis('tight')
    ax.table(cellText=statictics_table, loc='center')
    fig.tight_layout()
    plt.show()

# %%
def show_feature_mfcc_vectors(feature_vectors, K, title1):
    N_MFCC = 13
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    n = np.arange(N_MFCC)
    plt.figure(figsize=(20,10))
    plt.title(title1)
    plt.plot(n, feature_vectors[0, :], 'b', label=vowel_files[0])
    plt.plot(n, feature_vectors[K, :], 'y', label=vowel_files[1])
    plt.plot(n, feature_vectors[2 * K, :], 'darkcyan', label=vowel_files[2])
    plt.plot(n, feature_vectors[3 * K, :], 'orange', label=vowel_files[3])
    plt.plot(n, feature_vectors[4 * K, :], 'r', label=vowel_files[4])
    plt.legend()
    plt.xlabel('Chỉ số')
    plt.ylabel('Hệ số MFCC')
    plt.show()
    plt.figure()

# %%
def show_confusion_matrix(confusion_matrix, title, time_processing_vowels):
    for row in confusion_matrix[1:]:
        if type(row[-1]) == float:  
            row[-1] = "{:.1f}".format(row[-1])
        else:
            row[-1] = ""
    df_cm = DataFrame(
        [row[1:] for row in confusion_matrix[1:]], 
        columns=confusion_matrix[0][1:],  
        index=[row[0] for row in confusion_matrix[1:]]  
    )

    avg_time_vowels = [round(item['avg_time'],4) for item in time_processing_vowels]
    avg_time_vowels.append("")
    df_cm['Time-Avg'] = avg_time_vowels
    fig, ax = plt.subplots(figsize=(14, 5))  
    ax.set_title(title, color='blue', loc='center', fontweight='bold')
    ax.axis('off')  
    tab = ax.table(cellText=df_cm.values, cellLoc='center', loc='center', rowLabels=df_cm.index, colLabels=df_cm.columns)
    tab.auto_set_font_size(False)
    tab.set_fontsize(14)
    tab.scale(1, 1.4)
    max_index = df_cm.iloc[:-1, -2].astype(float).idxmax()  # Tìm percent cao nhất
    min_index = df_cm.iloc[:-1, -2].astype(float).idxmin()  # Tìm percent thấp nhất


    for key, cell in tab.get_celld().items():
        if key[0] == 0:
            cell.set_text_props(color='black', fontweight='bold')
            cell.set_facecolor('lightgrey')
            
    for (i, row) in enumerate(df_cm.iterrows(), start=1):
        if row[0] == max_index :  # Highlight dòng có percent cao nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j-1)].set_facecolor('lightgreen')
        if row[0] == min_index:   # Highlight dòng có percent thấp nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j-1)].set_facecolor('salmon')
    
    plt.show()

# %%
def show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime):
    plt.figure()
    plt.plot(np.arange(0, len(data) * T, T), data) # tín hiệu sau khi chuẩn hóa
    plt.title("Speech and Stable Area of the Signal ")
    # Vẽ vùng tiếng nói
    plt.axvline(x=(speech_area[0]) * sample_shift_frame * T, color='r', linestyle='--', label="Start of Speech")
    plt.axvline(x=(speech_area[-1]) * sample_shift_frame * T, color='r', linestyle='--', label="End of Speech")
    # Vẽ vùng ổn định
    plt.axvline(x=(startTime) * sample_shift_frame * T, color='b', linestyle='--', label="Start of Stable Speech")
    plt.axvline(x=(endTime) * sample_shift_frame * T, color='b', linestyle='--', label="End of Stable Speech")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Khoảng cách Euclidean giữa 2 vector
def euclideanDistance(v1, v2):
    return np.linalg.norm(v1 - v2)

# %%
def accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx):
    total_percent = 0
    for i in range(5):
        total_correct = confusion_matrix[i + 1][i + 1] # Số lần nhận dạng đúng
        confusion_matrix[i + 1][6] = f"{total_correct}/21" 
        percent = float(total_correct) / 21 * 100 # Phần trăm nhận dạng đúng
        confusion_matrix[i + 1][7] = percent
        total_percent += percent
    confusion_matrix[6][7] = total_percent / 5
    accuracy_percent_synthesis[1][idx] = total_percent / 5 # Độ chính xác trung bình
    total_percent = 0
    if (idx == 4):
        for i in range(4):
            total_percent += accuracy_percent_synthesis[1][i + 1]
        accuracy_percent_synthesis[1][idx + 1] = total_percent / 4 # Độ chính xác trung bình của tất cả các K
    return confusion_matrix, accuracy_percent_synthesis

# %%
def find_speech_area(files, frame_length, frame_shift):
    sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
    T = 1 / sampleRate # Chu kỳ
    # 1s -> 16K sample
    sample_one_frame = round(frame_length * sampleRate) # số mẫu 1 khung
    sample_shift_frame = round(frame_shift * sampleRate) # số mẫu khoảng dịch
    # Tổng số khung thu được = (số lượng mẫu - số mẫu 1 khung) // số mẫu khoảng dịch + 1
    total_number_frame = (len(data) - sample_one_frame) // sample_shift_frame + 1
    # Chuẩn hóa data về biên độ [-1, 1]
    data = data / abs(max(data))
    # Chia data thành các frame
    list_frames = [data[i * sample_shift_frame : i * sample_shift_frame + sample_one_frame] for i in range(total_number_frame)]
    list_frames = np.array(list_frames)
    ste_frame = np.sum(list_frames ** 2, axis=1) # STE từng frame
    ste_frame /= max(ste_frame) # Chuẩn hóa STE
    threshold = 0.01 # Ngưỡng thủ công
    speech_area = np.where(ste_frame >= threshold)[0] # tìm vùng tiếng nói
    return list_frames, data, T, sample_shift_frame, speech_area

# %%
def find_stable_area(files, frame_length, frame_shift): # tìm vùng ổn định
    list_frames, data, T, sample_shift_frame, speech_area = find_speech_area(files, frame_length, frame_shift)
    dist = int(np.ceil((speech_area[-1] - speech_area[0]) / 3)) # Chia thành 3 đoạn bằng nhau
    startTime = speech_area[0] + dist # Vị trí bắt đầu vùng ổn định
    endTime = speech_area[0] + 2 * dist # Vị trí kết thúc vùng ổn định
    return list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area

# %%
def find_vowel_feature_mfcc_vectors(list_frames, timeStart, timeEnd, N_MFCC, Fs, frame_length, frame_shift):
    coef_mfcc_vectors = []
    frame_length_sample = round(frame_length * Fs)   # Độ dài khung (frame length) chuyển đổi sang mẫu
    hop_length_sample = round(frame_shift * Fs)     # Khoảng dịch khung (frame step) chuyển đổi sang mẫu
    for k in range(timeStart, timeEnd + 1): 
        coef_mfcc_vector = librosa.feature.mfcc(y=list_frames[k, :], sr=16000, n_mfcc=N_MFCC+1, n_fft=frame_length_sample, hop_length=hop_length_sample, 
                                        window='hamming')[1:,]  
        coef_mfcc_vectors.append(coef_mfcc_vector.mean(axis=1))  
    return np.array(coef_mfcc_vectors)

# %%
def recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs):
    N_MFCC = 13
    folder_names = [item['folder_name'] for item in audio_test_file_paths]
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    vowels = ["a", "e", "i", "o", "u"]
    num_folders = len(folder_names)
    num_files = len(vowel_files)
    statictics_table = np.zeros((num_folders + 1, num_files + 1), dtype=object)
    statictics_table[0, 0] = ""
    statictics_table[1:, 0] = folder_names
    statictics_table[0, 1:] = vowel_files
    confusion_matrix = [
        ["", "a", "e", "i", "o", "u", "Tỉ lệ", "ĐCX (%)"],
        ["  a  ", 0, 0, 0, 0, 0, 0, 0],
        ["  e  ", 0, 0, 0, 0, 0, 0, 0],
        ["  i  ", 0, 0, 0, 0, 0, 0, 0],
        ["  o  ", 0, 0, 0, 0, 0, 0, 0],
        ["  u  ", 0, 0, 0, 0, 0, 0, 0],
        ["     ", "", "", "", "", "", "", 0]
    ]

    time_processing_vowels = []
    for i in range(num_files):
        vowel_files_in_paths = find_vowel_files(audio_test_file_paths, vowel_files[i])
        j = -1
        time_processing_vowel = 0
        for file in vowel_files_in_paths:
            start_time = time.time()

            j += 1
            # Tìm vùng ổn định
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(file, frame_length, frame_shift)
            # Tìm vector đặc trưng MFCC
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            # Tìm khoảng cách ngắn nhất
            min_dist = euclideanDistance(kmean_mfcc_feature_vectors[0, :], vowel_feature_mfcc_vector)
            index = 0
            for k in range(1, 5 * K): 
                min_t = euclideanDistance(kmean_mfcc_feature_vectors[k, :], vowel_feature_mfcc_vector)
                if min_t < min_dist:
                    min_dist = min_t
                    index = k
            index = index // K            
            # Điền vào bảng
            statictics_table[j + 1, i + 1] = vowels[index]
            confusion_matrix[i + 1][index + 1] += 1

            end_time = time.time()
            time_processing_vowel += (end_time - start_time)

            print(f"Consuming time for {vowels[index]} in {file}: {end_time - start_time}\n")
        avg_time_processing_vowel = time_processing_vowel /len(vowel_files_in_paths)
        vowel_label = file.split('.wav')[0]
        print("label:",vowel_label)
        item = {
            'vowel':vowel_label[-1],
            'avg_time': avg_time_processing_vowel
        }
        time_processing_vowels.append(item)
    print("time consuming vowel:", time_processing_vowels)
    return statictics_table, confusion_matrix, time_processing_vowels

# %%
def find_kmean_vectors(frame_length, frame_shift, Fs, K):
    N_MFCC = 13 # Số lượng hệ số MFCC
    kmean_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC khi áp dụng Kmean
    vowel_file = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] # file nguyên âm
    for i in range(len(vowel_file)): # Chạy từng nguyên âm
        vowel_files_in_paths = find_vowel_files(audio_train_file_paths, vowel_file[i]) # Lấy đường dẫn có vowel_file
        vowel_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC của 1 nguyên âm nhiều người nói
        for files in vowel_files_in_paths: # Duyệt từng file 
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(files, frame_length, frame_shift) # Tìm vùng ổn định
            # Tìm vector đặc trưng MFCC 1 nguyên âm 1 người nói
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            vowel_feature_mfcc_vectors = np.vstack((vowel_feature_mfcc_vectors, vowel_feature_mfcc_vector))
        # Tiến hành chia cụm
        kmeans = KMeans(n_clusters=K, random_state=0).fit(vowel_feature_mfcc_vectors)
        centroids = kmeans.cluster_centers_ # Tìm trung tâm cụm
        kmean_feature_mfcc_vectors = np.vstack((kmean_feature_mfcc_vectors, centroids))
    return kmean_feature_mfcc_vectors # 5 * K vector kmean

# %%
def Bai3():
    frame_length = 0.02 # Độ dài khung
    frame_shift = 0.01 # Độ dịch khung
    Fs = 16000
    # Vẽ 1 tín hiệu từ file để kiểm tra vùng ổn định
    list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area("NguyenAmHuanLuyen-16k/23MTL/i.wav", frame_length, frame_shift)
    show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime)
    accuracy_percent_synthesis = np.zeros((2, 6), dtype=object)
    K_arr = ["K = 2", "K = 3", "K = 4", "K = 5", "ĐCXTB (%)"]
    N_arr = ["N_MFCC = 13"]
    accuracy_percent_synthesis[0, 0] = ""
    accuracy_percent_synthesis[1:, 0] = N_arr
    accuracy_percent_synthesis[0, 1:] = K_arr
    idx = 0
    for K in range(2, 6): # K chạy từ 2 -> 5
        kmean_mfcc_feature_vectors = find_kmean_vectors(frame_length, frame_shift, Fs, K) # Tìm 5 * K vector đặc trưng
        
        statictics_table, confusion_matrix, time_processing_vowels = recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs)
        idx += 1
        confusion_matrix, accuracy_percent_synthesis = accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx)
        # Tiến hành hiển thị vector đặc trưng
        title = f"Vector đặc trưng MFCC với N_MFCC = 13 và K = {K}"
        show_feature_mfcc_vectors(kmean_mfcc_feature_vectors, K, title)
        # In ra bảng thống kê
        title = f"Kết quả nhận dạng với N_MFCC = 13 và K = {K}"
        show_statictics_table(statictics_table, title)
        title = f"Ma trận nhầm lẫn với N_MFCC = 13 và K = {K}"
        show_confusion_matrix(confusion_matrix, title, time_processing_vowels)
        title = f"Độ chính xác nhận dạng tổng hợp theo số cụm K"
    show_accuracy_matrix(accuracy_percent_synthesis, title)

# %%
if __name__ == "__main__":
    Bai3()
# Out:
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.037236928939819336
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.05799221992492676
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.05430769920349121
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.05761408805847168
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.029668807983398438
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.040676116943359375
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.04513406753540039
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.024763822555541992
#
# Consuming time for a in NguyenAmKiemThu-16k/12FTD/a.wav: 0.0432279109954834
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.03955483436584473
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.04858112335205078
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.02985692024230957
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.03165793418884277
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.048660993576049805
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.0399930477142334
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.035729169845581055
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.0469818115234375
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.032073020935058594
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.02945995330810547
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.038768768310546875
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.036582231521606445
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.027226924896240234
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.04017305374145508
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.036199092864990234
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.030757904052734375
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.030224084854125977
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.03476691246032715
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.04512524604797363
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/e.wav: 0.02403879165649414
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.043591976165771484
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.03975510597229004
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.04345297813415527
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.026463985443115234
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.03466987609863281
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.04138517379760742
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.04400992393493652
#
# Consuming time for e in NguyenAmKiemThu-16k/04MHB/e.wav: 0.04060697555541992
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.04148507118225098
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.029210805892944336
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/e.wav: 0.02797412872314453
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/e.wav: 0.05094790458679199
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/e.wav: 0.04135704040527344
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.03332781791687012
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.05283713340759277
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.05052495002746582
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.07234501838684082
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.03187417984008789
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.03431200981140137
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.03341102600097656
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.02734684944152832
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.046837806701660156
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.056535959243774414
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.054064035415649414
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.03561687469482422
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.03853201866149902
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.04779505729675293
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.06256985664367676
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.04097414016723633
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.056756019592285156
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.039845943450927734
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/i.wav: 0.04331803321838379
#
# Consuming time for i in NguyenAmKiemThu-16k/02FVA/i.wav: 0.048048973083496094
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.03941702842712402
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.026307106018066406
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.04019618034362793
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.03610682487487793
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.028957843780517578
#
# Consuming time for o in NguyenAmKiemThu-16k/11MVD/o.wav: 0.03193378448486328
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.03326702117919922
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.04290771484375
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.023952960968017578
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.042829036712646484
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.0484621524810791
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.04693007469177246
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.026890993118286133
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/o.wav: 0.029572248458862305
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.05624675750732422
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.06020498275756836
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.04129815101623535
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.0411839485168457
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.025416851043701172
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.027767181396484375
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.04037976264953613
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.03181314468383789
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.024827957153320312
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.0357050895690918
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/u.wav: 0.06579995155334473
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.024617910385131836
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.029047012329101562
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.028819799423217773
#
# Consuming time for u in NguyenAmKiemThu-16k/05MVB/u.wav: 0.03683781623840332
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.02622509002685547
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.0415799617767334
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.032959938049316406
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.03621411323547363
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.02395796775817871
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.03212714195251465
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.04047584533691406
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.04976987838745117
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.04348111152648926
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.04435300827026367
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.02769017219543457
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/u.wav: 0.10130572319030762
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.049008846282958984
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.035147905349731445
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.04040578433445522}, {'vowel': 'e', 'avg_time': 0.03682966459365118}, {'vowel': 'i', 'avg_time': 0.04506146340143113}, {'vowel': 'o', 'avg_time': 0.037267843882242836}, {'vowel': 'u', 'avg_time': 0.03952153523763021}]
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.03516793251037598
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.06810784339904785
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.0371091365814209
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.04121589660644531
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.028852224349975586
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03270697593688965
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.041235923767089844
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.02122020721435547
#
# Consuming time for a in NguyenAmKiemThu-16k/12FTD/a.wav: 0.038065195083618164
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.0348820686340332
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/a.wav: 0.04073810577392578
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.0232999324798584
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.03143906593322754
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.04332089424133301
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.03579878807067871
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.032224178314208984
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.03749394416809082
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.023663759231567383
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.02623605728149414
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.04296278953552246
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.032113075256347656
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.022777795791625977
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.03226423263549805
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.028452634811401367
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.025786876678466797
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.0319671630859375
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.03523993492126465
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.039216041564941406
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.0215451717376709
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.03732490539550781
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.03570890426635742
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.03987717628479004
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.023034095764160156
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.033891916275024414
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.03887796401977539
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.03667879104614258
#
# Consuming time for e in NguyenAmKiemThu-16k/04MHB/e.wav: 0.03720712661743164
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.03831887245178223
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.02554011344909668
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/e.wav: 0.021348237991333008
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/e.wav: 0.04516887664794922
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/e.wav: 0.03093409538269043
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.023262977600097656
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.02932286262512207
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.02893805503845215
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.05676603317260742
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.024072885513305664
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.030210018157958984
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.03101801872253418
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.02114725112915039
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.04631924629211426
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.036818742752075195
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.03593301773071289
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.0254518985748291
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.030743837356567383
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.0373539924621582
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.04514503479003906
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.03209686279296875
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.03714799880981445
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.020851850509643555
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/i.wav: 0.03943276405334473
#
# Consuming time for i in NguyenAmKiemThu-16k/02FVA/i.wav: 0.0392918586730957
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.028038978576660156
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.023462772369384766
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.03354907035827637
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.03177618980407715
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.025763273239135742
#
# Consuming time for o in NguyenAmKiemThu-16k/11MVD/o.wav: 0.02958989143371582
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.03959512710571289
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.044567108154296875
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.0208590030670166
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.0376431941986084
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.037287235260009766
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.03763294219970703
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.024168014526367188
#
# Consuming time for o in NguyenAmKiemThu-16k/07FTC/o.wav: 0.02614307403564453
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.03832697868347168
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.04819011688232422
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.03438591957092285
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.038935184478759766
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.025419950485229492
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.025347232818603516
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.03384900093078613
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.027966976165771484
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.02031731605529785
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.028123140335083008
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/u.wav: 0.05823206901550293
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.02134561538696289
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.024682998657226562
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.024011850357055664
#
# Consuming time for u in NguyenAmKiemThu-16k/05MVB/u.wav: 0.0322880744934082
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.019986867904663086
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.03368520736694336
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.028730154037475586
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.03060603141784668
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.02085399627685547
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.025902986526489258
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.02925896644592285
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.03365182876586914
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.03680300712585449
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.03126406669616699
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.019943952560424805
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/u.wav: 0.061100006103515625
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.03413224220275879
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.030709028244018555
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03561209496997651}, {'vowel': 'e', 'avg_time': 0.03243623461042132}, {'vowel': 'i', 'avg_time': 0.03330305644444057}, {'vowel': 'o', 'avg_time': 0.0325932502746582}, {'vowel': 'u', 'avg_time': 0.03074425742739723}]
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.03139925003051758
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.042218923568725586
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.03986501693725586
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.0439910888671875
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.032896995544433594
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03241276741027832
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.03910493850708008
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.021455049514770508
#
# Consuming time for e in NguyenAmKiemThu-16k/12FTD/a.wav: 0.03624081611633301
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.03321409225463867
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.04003572463989258
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.022175073623657227
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.026886940002441406
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/a.wav: 0.04849100112915039
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.03632020950317383
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.031193017959594727
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.03628182411193848
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.022037029266357422
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.02535080909729004
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.03165721893310547
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.030761003494262695
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.023495197296142578
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.030382156372070312
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.027769804000854492
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.024657249450683594
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.024908065795898438
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.024327993392944336
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.034082889556884766
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.021739721298217773
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.03514385223388672
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.03398323059082031
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.03673195838928223
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.02248215675354004
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.0291290283203125
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.03699302673339844
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.0369410514831543
#
# Consuming time for e in NguyenAmKiemThu-16k/04MHB/e.wav: 0.03611326217651367
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.034819841384887695
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.025834083557128906
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/e.wav: 0.020488977432250977
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/e.wav: 0.04056906700134277
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/e.wav: 0.029313087463378906
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.02449488639831543
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.028629064559936523
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.028271913528442383
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.05736279487609863
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.027172088623046875
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.028471946716308594
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.03036785125732422
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.02226090431213379
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.03239798545837402
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.03237581253051758
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.033267974853515625
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.024498939514160156
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.026316165924072266
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.03419208526611328
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.04635286331176758
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.03050971031188965
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.03577780723571777
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.020013809204101562
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/i.wav: 0.035756826400756836
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/i.wav: 0.03587794303894043
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.027611970901489258
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.0240631103515625
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.03397512435913086
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.03112030029296875
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.025552749633789062
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/o.wav: 0.0248260498046875
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.026234149932861328
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.036190032958984375
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.019672155380249023
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.03870987892150879
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.03674507141113281
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.03378605842590332
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.023008108139038086
#
# Consuming time for o in NguyenAmKiemThu-16k/07FTC/o.wav: 0.024816274642944336
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.03666520118713379
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.04527115821838379
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.04258394241333008
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.0331876277923584
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.02210378646850586
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.02231574058532715
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.03405189514160156
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.02684783935546875
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.0198819637298584
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.02776479721069336
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/u.wav: 0.09098100662231445
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.027957916259765625
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.02498006820678711
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.02492690086364746
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/u.wav: 0.03181576728820801
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.02009892463684082
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.03421282768249512
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.02792811393737793
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.0319669246673584
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.020354032516479492
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.026185035705566406
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.02968311309814453
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/u.wav: 0.03368878364562988
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.02984309196472168
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.030821800231933594
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.019855022430419922
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/u.wav: 0.06054186820983887
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.03479504585266113
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.0293881893157959
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03352327573867071}, {'vowel': 'e', 'avg_time': 0.029995509556361606}, {'vowel': 'i', 'avg_time': 0.03152292115347726}, {'vowel': 'o', 'avg_time': 0.030558393115089053}, {'vowel': 'u', 'avg_time': 0.03227005686078753}]
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /var/folders/ty/3_3ks_2d3n1d9c11s42742xc0000gn/T/ipykernel_6490/567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# /Users/lequangnhat/My Study/4-Signal-Processing/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k/22MHL/a.wav: 0.03458094596862793
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/a.wav: 0.041069746017456055
#
# Consuming time for a in NguyenAmKiemThu-16k/03MAB/a.wav: 0.03577589988708496
#
# Consuming time for a in NguyenAmKiemThu-16k/08MLD/a.wav: 0.04537606239318848
#
# Consuming time for a in NguyenAmKiemThu-16k/11MVD/a.wav: 0.030920028686523438
#
# Consuming time for a in NguyenAmKiemThu-16k/09MPD/a.wav: 0.03329586982727051
#
# Consuming time for a in NguyenAmKiemThu-16k/05MVB/a.wav: 0.040743112564086914
#
# Consuming time for a in NguyenAmKiemThu-16k/20MVK/a.wav: 0.021303176879882812
#
# Consuming time for e in NguyenAmKiemThu-16k/12FTD/a.wav: 0.03637814521789551
#
# Consuming time for a in NguyenAmKiemThu-16k/06FTB/a.wav: 0.033143043518066406
#
# Consuming time for a in NguyenAmKiemThu-16k/14FHH/a.wav: 0.03983592987060547
#
# Consuming time for a in NguyenAmKiemThu-16k/21MTL/a.wav: 0.02214503288269043
#
# Consuming time for a in NguyenAmKiemThu-16k/07FTC/a.wav: 0.028406143188476562
#
# Consuming time for a in NguyenAmKiemThu-16k/19MXK/a.wav: 0.044111013412475586
#
# Consuming time for a in NguyenAmKiemThu-16k/18MNK/a.wav: 0.034767866134643555
#
# Consuming time for a in NguyenAmKiemThu-16k/04MHB/a.wav: 0.03129005432128906
#
# Consuming time for a in NguyenAmKiemThu-16k/15MMH/a.wav: 0.035987138748168945
#
# Consuming time for a in NguyenAmKiemThu-16k/01MDA/a.wav: 0.022385120391845703
#
# Consuming time for a in NguyenAmKiemThu-16k/10MSD/a.wav: 0.02495598793029785
#
# Consuming time for a in NguyenAmKiemThu-16k/02FVA/a.wav: 0.03169107437133789
#
# Consuming time for a in NguyenAmKiemThu-16k/17MTH/a.wav: 0.03764677047729492
#
# label: NguyenAmKiemThu-16k/17MTH/a
# Consuming time for e in NguyenAmKiemThu-16k/22MHL/e.wav: 0.028961896896362305
#
# Consuming time for e in NguyenAmKiemThu-16k/16FTH/e.wav: 0.038265228271484375
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/e.wav: 0.03366494178771973
#
# Consuming time for e in NguyenAmKiemThu-16k/08MLD/e.wav: 0.03755807876586914
#
# Consuming time for e in NguyenAmKiemThu-16k/11MVD/e.wav: 0.029240131378173828
#
# Consuming time for e in NguyenAmKiemThu-16k/09MPD/e.wav: 0.02640819549560547
#
# Consuming time for e in NguyenAmKiemThu-16k/05MVB/e.wav: 0.03784608840942383
#
# Consuming time for e in NguyenAmKiemThu-16k/20MVK/e.wav: 0.021306753158569336
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/e.wav: 0.03519487380981445
#
# Consuming time for e in NguyenAmKiemThu-16k/06FTB/e.wav: 0.03446173667907715
#
# Consuming time for e in NguyenAmKiemThu-16k/14FHH/e.wav: 0.039865732192993164
#
# Consuming time for e in NguyenAmKiemThu-16k/21MTL/e.wav: 0.02303910255432129
#
# Consuming time for e in NguyenAmKiemThu-16k/07FTC/e.wav: 0.02920389175415039
#
# Consuming time for e in NguyenAmKiemThu-16k/19MXK/e.wav: 0.04020810127258301
#
# Consuming time for e in NguyenAmKiemThu-16k/18MNK/e.wav: 0.03500199317932129
#
# Consuming time for e in NguyenAmKiemThu-16k/04MHB/e.wav: 0.035549163818359375
#
# Consuming time for e in NguyenAmKiemThu-16k/15MMH/e.wav: 0.03527712821960449
#
# Consuming time for e in NguyenAmKiemThu-16k/01MDA/e.wav: 0.02462482452392578
#
# Consuming time for e in NguyenAmKiemThu-16k/10MSD/e.wav: 0.020631790161132812
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/e.wav: 0.06933999061584473
#
# Consuming time for e in NguyenAmKiemThu-16k/17MTH/e.wav: 0.049010276794433594
#
# label: NguyenAmKiemThu-16k/17MTH/e
# Consuming time for i in NguyenAmKiemThu-16k/22MHL/i.wav: 0.029012203216552734
#
# Consuming time for i in NguyenAmKiemThu-16k/16FTH/i.wav: 0.03508400917053223
#
# Consuming time for i in NguyenAmKiemThu-16k/03MAB/i.wav: 0.02901601791381836
#
# Consuming time for i in NguyenAmKiemThu-16k/08MLD/i.wav: 0.055513858795166016
#
# Consuming time for i in NguyenAmKiemThu-16k/11MVD/i.wav: 0.03087782859802246
#
# Consuming time for i in NguyenAmKiemThu-16k/09MPD/i.wav: 0.05487370491027832
#
# Consuming time for i in NguyenAmKiemThu-16k/05MVB/i.wav: 0.0627431869506836
#
# Consuming time for i in NguyenAmKiemThu-16k/20MVK/i.wav: 0.02225327491760254
#
# Consuming time for i in NguyenAmKiemThu-16k/12FTD/i.wav: 0.032132863998413086
#
# Consuming time for i in NguyenAmKiemThu-16k/06FTB/i.wav: 0.0344388484954834
#
# Consuming time for i in NguyenAmKiemThu-16k/14FHH/i.wav: 0.036109209060668945
#
# Consuming time for i in NguyenAmKiemThu-16k/21MTL/i.wav: 0.02491593360900879
#
# Consuming time for i in NguyenAmKiemThu-16k/07FTC/i.wav: 0.028529882431030273
#
# Consuming time for i in NguyenAmKiemThu-16k/19MXK/i.wav: 0.03582406044006348
#
# Consuming time for i in NguyenAmKiemThu-16k/18MNK/i.wav: 0.04179787635803223
#
# Consuming time for i in NguyenAmKiemThu-16k/04MHB/i.wav: 0.029591798782348633
#
# Consuming time for i in NguyenAmKiemThu-16k/15MMH/i.wav: 0.034559011459350586
#
# Consuming time for i in NguyenAmKiemThu-16k/01MDA/i.wav: 0.021380901336669922
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/i.wav: 0.03580284118652344
#
# Consuming time for e in NguyenAmKiemThu-16k/02FVA/i.wav: 0.03476881980895996
#
# Consuming time for i in NguyenAmKiemThu-16k/17MTH/i.wav: 0.02698230743408203
#
# label: NguyenAmKiemThu-16k/17MTH/i
# Consuming time for o in NguyenAmKiemThu-16k/22MHL/o.wav: 0.02200007438659668
#
# Consuming time for o in NguyenAmKiemThu-16k/16FTH/o.wav: 0.03229999542236328
#
# Consuming time for o in NguyenAmKiemThu-16k/03MAB/o.wav: 0.030390024185180664
#
# Consuming time for o in NguyenAmKiemThu-16k/08MLD/o.wav: 0.02752208709716797
#
# Consuming time for o in NguyenAmKiemThu-16k/11MVD/o.wav: 0.02722477912902832
#
# Consuming time for o in NguyenAmKiemThu-16k/09MPD/o.wav: 0.026167869567871094
#
# Consuming time for o in NguyenAmKiemThu-16k/05MVB/o.wav: 0.03677797317504883
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/o.wav: 0.020375728607177734
#
# Consuming time for o in NguyenAmKiemThu-16k/12FTD/o.wav: 0.038484811782836914
#
# Consuming time for o in NguyenAmKiemThu-16k/06FTB/o.wav: 0.035735130310058594
#
# Consuming time for o in NguyenAmKiemThu-16k/14FHH/o.wav: 0.03684282302856445
#
# Consuming time for o in NguyenAmKiemThu-16k/21MTL/o.wav: 0.02321791648864746
#
# Consuming time for o in NguyenAmKiemThu-16k/07FTC/o.wav: 0.025367021560668945
#
# Consuming time for o in NguyenAmKiemThu-16k/19MXK/o.wav: 0.038053035736083984
#
# Consuming time for o in NguyenAmKiemThu-16k/18MNK/o.wav: 0.04482102394104004
#
# Consuming time for o in NguyenAmKiemThu-16k/04MHB/o.wav: 0.032469987869262695
#
# Consuming time for o in NguyenAmKiemThu-16k/15MMH/o.wav: 0.0407259464263916
#
# Consuming time for o in NguyenAmKiemThu-16k/01MDA/o.wav: 0.04314899444580078
#
# Consuming time for o in NguyenAmKiemThu-16k/10MSD/o.wav: 0.035967111587524414
#
# Consuming time for o in NguyenAmKiemThu-16k/02FVA/o.wav: 0.03597283363342285
#
# Consuming time for o in NguyenAmKiemThu-16k/17MTH/o.wav: 0.027665138244628906
#
# label: NguyenAmKiemThu-16k/17MTH/o
# Consuming time for u in NguyenAmKiemThu-16k/22MHL/u.wav: 0.020457983016967773
#
# Consuming time for u in NguyenAmKiemThu-16k/16FTH/u.wav: 0.03223705291748047
#
# Consuming time for e in NguyenAmKiemThu-16k/03MAB/u.wav: 0.06457710266113281
#
# Consuming time for u in NguyenAmKiemThu-16k/08MLD/u.wav: 0.022901296615600586
#
# Consuming time for u in NguyenAmKiemThu-16k/11MVD/u.wav: 0.026612043380737305
#
# Consuming time for u in NguyenAmKiemThu-16k/09MPD/u.wav: 0.026157140731811523
#
# Consuming time for u in NguyenAmKiemThu-16k/05MVB/u.wav: 0.03480982780456543
#
# Consuming time for u in NguyenAmKiemThu-16k/20MVK/u.wav: 0.02379775047302246
#
# Consuming time for u in NguyenAmKiemThu-16k/12FTD/u.wav: 0.04198598861694336
#
# Consuming time for u in NguyenAmKiemThu-16k/06FTB/u.wav: 0.039694786071777344
#
# Consuming time for u in NguyenAmKiemThu-16k/14FHH/u.wav: 0.040209054946899414
#
# Consuming time for u in NguyenAmKiemThu-16k/21MTL/u.wav: 0.027591228485107422
#
# Consuming time for u in NguyenAmKiemThu-16k/07FTC/u.wav: 0.03473520278930664
#
# Consuming time for u in NguyenAmKiemThu-16k/19MXK/u.wav: 0.033322811126708984
#
# Consuming time for u in NguyenAmKiemThu-16k/18MNK/u.wav: 0.03387904167175293
#
# Consuming time for u in NguyenAmKiemThu-16k/04MHB/u.wav: 0.0301361083984375
#
# Consuming time for u in NguyenAmKiemThu-16k/15MMH/u.wav: 0.0331120491027832
#
# Consuming time for u in NguyenAmKiemThu-16k/01MDA/u.wav: 0.020399093627929688
#
# Consuming time for i in NguyenAmKiemThu-16k/10MSD/u.wav: 0.05762791633605957
#
# Consuming time for u in NguyenAmKiemThu-16k/02FVA/u.wav: 0.03323483467102051
#
# Consuming time for u in NguyenAmKiemThu-16k/17MTH/u.wav: 0.028297901153564453
#
# label: NguyenAmKiemThu-16k/17MTH/u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03360991250900995}, {'vowel': 'e', 'avg_time': 0.034507615225655694}, {'vowel': 'i', 'avg_time': 0.03505754470825195}, {'vowel': 'o', 'avg_time': 0.03243953841073172}, {'vowel': 'u', 'avg_time': 0.03360839117140997}]
