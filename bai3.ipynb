# %%
import numpy as np
import scipy.signal
from scipy.io import wavfile
import scipy.io.wavfile
import librosa
import matplotlib.pyplot as plt
import os
from pandas import DataFrame
import time
from scipy.signal.windows import hamming
from sklearn.cluster import KMeans

# %%
# Lấy list wav files từ 1 folder
def get_wav_files(folder_path):
    wav_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".wav"):
                wav_files.append(os.path.join(root, file))
    return wav_files

base_audio_train_folder = "NguyenAmHuanLuyen-16k"
audio_train_folders = [os.path.join(base_audio_train_folder, folder) for folder in os.listdir(base_audio_train_folder)]
audio_train_file_paths = []
for folder in audio_train_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_train_file_paths.append(item)

base_audio_test_folder = "NguyenAmKiemThu-16k"
audio_test_folders = [os.path.join(base_audio_test_folder, folder) for folder in os.listdir(base_audio_test_folder)]
audio_test_file_paths = []
for folder in audio_test_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_test_file_paths.append(item)

# %%
def find_vowel_files(audio_file_paths, vowel_file):
    vowel_files_in_paths = []
    for item in audio_file_paths:
        # Tìm các file trong list tương ứng của từng folder
        matching_files = [f for f in item['audio_files'] if os.path.basename(f) in vowel_file]
        if matching_files:
            vowel_files_in_paths.extend(matching_files)
    return vowel_files_in_paths

# %%
def format_accuracy_matrix(matrix):
    formatted_matrix = matrix.copy()
    for i in range(1, matrix.shape[0]):
        for j in range(1, matrix.shape[1]):
            # Chỉ format các ô không phải tiêu đề (giả định đây là số hoặc None)
            if matrix[i, j] is not None:
                formatted_matrix[i, j] = f"{matrix[i, j]:.1f}"
    return formatted_matrix

# %%
def show_accuracy_matrix(accuracy_percent_synthesis, title):
    formatted = format_accuracy_matrix(accuracy_percent_synthesis)
    fig, ax = plt.subplots(figsize=(8, 3))  # Modify the size as needed
    ax.set_title(title, color='blue', loc='center',fontweight='bold')
    ax.axis('off')
    ax.axis('tight')
    table = ax.table(cellText=formatted, loc='center', cellLoc='center', edges='closed')
    table.auto_set_column_width(col=list(range(len(formatted[0]))))  
    table.auto_set_font_size(False)  
    table.set_fontsize(11)  
    fig.tight_layout()
    plt.show()

# %%
def show_statictics_table(statictics_table, title):
    # Vẽ bảng thống kê
    fig, ax = plt.subplots()
    ax.set_title(title)
    ax.axis('off')
    ax.axis('tight')
    ax.table(cellText=statictics_table, loc='center')
    fig.tight_layout()
    plt.show()

# %%
def show_feature_mfcc_vectors(feature_vectors, K, title1):
    N_MFCC = 13
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    n = np.arange(N_MFCC)
    plt.figure(figsize=(20,10))
    plt.title(title1)
    plt.plot(n, feature_vectors[0, :], 'b', label=vowel_files[0])
    plt.plot(n, feature_vectors[K, :], 'y', label=vowel_files[1])
    plt.plot(n, feature_vectors[2 * K, :], 'darkcyan', label=vowel_files[2])
    plt.plot(n, feature_vectors[3 * K, :], 'orange', label=vowel_files[3])
    plt.plot(n, feature_vectors[4 * K, :], 'r', label=vowel_files[4])
    plt.legend()
    plt.xlabel('Chỉ số')
    plt.ylabel('Hệ số MFCC')
    plt.show()
    plt.figure()

# %%
def show_confusion_matrix(confusion_matrix, title, time_processing_vowels):
    for row in confusion_matrix[1:]:
        if type(row[-1]) == float:  
            row[-1] = "{:.1f}".format(row[-1])
        else:
            row[-1] = ""
    df_cm = DataFrame(
        [row[1:] for row in confusion_matrix[1:]], 
        columns=confusion_matrix[0][1:],  
        index=[row[0] for row in confusion_matrix[1:]]  
    )

    avg_time_vowels = [round(item['avg_time'],4) for item in time_processing_vowels]
    avg_time_vowels.append("")
    df_cm['Time-Avg'] = avg_time_vowels
    fig, ax = plt.subplots(figsize=(14, 5))  
    ax.set_title(title, color='blue', loc='center', fontweight='bold')
    ax.axis('off')  
    tab = ax.table(cellText=df_cm.values, cellLoc='center', loc='center', rowLabels=df_cm.index, colLabels=df_cm.columns)
    tab.auto_set_font_size(False)
    tab.set_fontsize(14)
    tab.scale(1, 1.4)
    max_index = df_cm.iloc[:-1, -2].astype(float).idxmax()  # Tìm percent cao nhất
    min_index = df_cm.iloc[:-1, -2].astype(float).idxmin()  # Tìm percent thấp nhất


    for key, cell in tab.get_celld().items():
        if key[0] == 0:
            cell.set_text_props(color='black', fontweight='bold')
            cell.set_facecolor('lightgrey')
            
    for (i, row) in enumerate(df_cm.iterrows(), start=1):
        if row[0] == max_index :  # Highlight dòng có percent cao nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j-1)].set_facecolor('lightgreen')
        if row[0] == min_index:   # Highlight dòng có percent thấp nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j-1)].set_facecolor('salmon')
    
    plt.show()

# %%
def show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime):
    plt.figure()
    plt.plot(np.arange(0, len(data) * T, T), data) # tín hiệu sau khi chuẩn hóa
    plt.title("Speech and Stable Area of the Signal ")
    # Vẽ vùng tiếng nói
    plt.axvline(x=(speech_area[0]) * sample_shift_frame * T, color='r', linestyle='--', label="Start of Speech")
    plt.axvline(x=(speech_area[-1]) * sample_shift_frame * T, color='r', linestyle='--', label="End of Speech")
    # Vẽ vùng ổn định
    plt.axvline(x=(startTime) * sample_shift_frame * T, color='b', linestyle='--', label="Start of Stable Speech")
    plt.axvline(x=(endTime) * sample_shift_frame * T, color='b', linestyle='--', label="End of Stable Speech")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Khoảng cách Euclidean giữa 2 vector
def euclideanDistance(v1, v2):
    return np.linalg.norm(v1 - v2)

# %%
def accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx):
    total_percent = 0
    for i in range(5):
        total_correct = confusion_matrix[i + 1][i + 1] # Số lần nhận dạng đúng
        confusion_matrix[i + 1][6] = f"{total_correct}/21" 
        percent = float(total_correct) / 21 * 100 # Phần trăm nhận dạng đúng
        confusion_matrix[i + 1][7] = percent
        total_percent += percent
    confusion_matrix[6][7] = total_percent / 5
    accuracy_percent_synthesis[1][idx] = total_percent / 5 # Độ chính xác trung bình
    total_percent = 0
    if (idx == 4):
        for i in range(4):
            total_percent += accuracy_percent_synthesis[1][i + 1]
        accuracy_percent_synthesis[1][idx + 1] = total_percent / 4 # Độ chính xác trung bình của tất cả các K
    return confusion_matrix, accuracy_percent_synthesis

# %%
def find_speech_area(files, frame_length, frame_shift):
    sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
    T = 1 / sampleRate # Chu kỳ
    # 1s -> 16K sample
    sample_one_frame = round(frame_length * sampleRate) # số mẫu 1 khung
    sample_shift_frame = round(frame_shift * sampleRate) # số mẫu khoảng dịch
    # Tổng số khung thu được = (số lượng mẫu - số mẫu 1 khung) // số mẫu khoảng dịch + 1
    total_number_frame = (len(data) - sample_one_frame) // sample_shift_frame + 1
    # Chuẩn hóa data về biên độ [-1, 1]
    data = data / abs(max(data))
    # Chia data thành các frame
    list_frames = [data[i * sample_shift_frame : i * sample_shift_frame + sample_one_frame] for i in range(total_number_frame)]
    list_frames = np.array(list_frames)
    ste_frame = np.sum(list_frames ** 2, axis=1) # STE từng frame
    ste_frame /= max(ste_frame) # Chuẩn hóa STE
    threshold = 0.03 # Ngưỡng thủ công
    speech_area = np.where(ste_frame >= threshold)[0] # tìm vùng tiếng nói
    return list_frames, data, T, sample_shift_frame, speech_area

# %%
def find_stable_area(files, frame_length, frame_shift): # tìm vùng ổn định
    list_frames, data, T, sample_shift_frame, speech_area = find_speech_area(files, frame_length, frame_shift)
    dist = int(np.ceil((speech_area[-1] - speech_area[0]) / 3)) # Chia thành 3 đoạn bằng nhau
    startTime = speech_area[0] + dist # Vị trí bắt đầu vùng ổn định
    endTime = speech_area[0] + 2 * dist # Vị trí kết thúc vùng ổn định
    return list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area

# %%
def find_vowel_feature_mfcc_vectors(list_frames, timeStart, timeEnd, N_MFCC, Fs, frame_length, frame_shift):
    coef_mfcc_vectors = []
    frame_length_sample = round(frame_length * Fs)   # Độ dài khung (frame length) chuyển đổi sang mẫu
    hop_length_sample = round(frame_shift * Fs)     # Khoảng dịch khung (frame step) chuyển đổi sang mẫu
    for k in range(timeStart, timeEnd + 1): 
        coef_mfcc_vector = librosa.feature.mfcc(y=list_frames[k, :], sr=16000, n_mfcc=N_MFCC+1, n_fft=frame_length_sample, hop_length=hop_length_sample, 
                                        window='hamming')[1:,]  
        coef_mfcc_vectors.append(coef_mfcc_vector.mean(axis=1))  
    return np.array(coef_mfcc_vectors)

# %%
def recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs):
    N_MFCC = 13
    folder_names = [item['folder_name'] for item in audio_test_file_paths]
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    vowels = ["a", "e", "i", "o", "u"]
    num_folders = len(folder_names)
    num_files = len(vowel_files)
    statictics_table = np.zeros((num_folders + 1, num_files + 1), dtype=object)
    statictics_table[0, 0] = ""
    statictics_table[1:, 0] = folder_names
    statictics_table[0, 1:] = vowel_files
    confusion_matrix = [
        ["", "a", "e", "i", "o", "u", "Tỉ lệ", "ĐCX (%)"],
        ["  a  ", 0, 0, 0, 0, 0, 0, 0],
        ["  e  ", 0, 0, 0, 0, 0, 0, 0],
        ["  i  ", 0, 0, 0, 0, 0, 0, 0],
        ["  o  ", 0, 0, 0, 0, 0, 0, 0],
        ["  u  ", 0, 0, 0, 0, 0, 0, 0],
        ["     ", "", "", "", "", "", "", 0]
    ]

    time_processing_vowels = []
    for i in range(num_files):
        vowel_files_in_paths = find_vowel_files(audio_test_file_paths, vowel_files[i])
        j = -1
        time_processing_vowel = 0
        for file in vowel_files_in_paths:
            start_time = time.time()

            j += 1
            # Tìm vùng ổn định
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(file, frame_length, frame_shift)
            # Tìm vector đặc trưng MFCC
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            # Tìm khoảng cách ngắn nhất
            min_dist = euclideanDistance(kmean_mfcc_feature_vectors[0, :], vowel_feature_mfcc_vector)
            index = 0
            for k in range(1, 5 * K): 
                min_t = euclideanDistance(kmean_mfcc_feature_vectors[k, :], vowel_feature_mfcc_vector)
                if min_t < min_dist:
                    min_dist = min_t
                    index = k
            index = index // K            
            # Điền vào bảng
            statictics_table[j + 1, i + 1] = vowels[index]
            confusion_matrix[i + 1][index + 1] += 1

            end_time = time.time()
            time_processing_vowel += (end_time - start_time)

            print(f"Consuming time for {vowels[index]} in {file}: {end_time - start_time}\n")
        avg_time_processing_vowel = time_processing_vowel /len(vowel_files_in_paths)
        vowel_label = file.split('.wav')[0]
        print("label:",vowel_label)
        item = {
            'vowel':vowel_label[-1],
            'avg_time': avg_time_processing_vowel
        }
        time_processing_vowels.append(item)
    print("time consuming vowel:", time_processing_vowels)
    return statictics_table, confusion_matrix, time_processing_vowels

# %%
def find_kmean_vectors(frame_length, frame_shift, Fs, K):
    N_MFCC = 13 # Số lượng hệ số MFCC
    kmean_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC khi áp dụng Kmean
    vowel_file = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] # file nguyên âm
    for i in range(len(vowel_file)): # Chạy từng nguyên âm
        vowel_files_in_paths = find_vowel_files(audio_train_file_paths, vowel_file[i]) # Lấy đường dẫn có vowel_file
        vowel_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC của 1 nguyên âm nhiều người nói
        for files in vowel_files_in_paths: # Duyệt từng file 
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(files, frame_length, frame_shift) # Tìm vùng ổn định
            # Tìm vector đặc trưng MFCC 1 nguyên âm 1 người nói
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            vowel_feature_mfcc_vectors = np.vstack((vowel_feature_mfcc_vectors, vowel_feature_mfcc_vector))
        # Tiến hành chia cụm
        kmeans = KMeans(n_clusters=K, random_state=0).fit(vowel_feature_mfcc_vectors)
        centroids = kmeans.cluster_centers_ # Tìm trung tâm cụm
        kmean_feature_mfcc_vectors = np.vstack((kmean_feature_mfcc_vectors, centroids))
    return kmean_feature_mfcc_vectors # 5 * K vector kmean

# %%
def Bai3():
    # threshold = 0.01
    frame_length = 0.03 # Độ dài khung
    frame_shift = 0.015 # Độ dịch khung
    Fs = 16000
    # Vẽ 1 tín hiệu từ file để kiểm tra vùng ổn định
    list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area("NguyenAmHuanLuyen-16k/23MTL/i.wav", frame_length, frame_shift)
    show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime)
    accuracy_percent_synthesis = np.zeros((2, 6), dtype=object)
    K_arr = ["K = 2", "K = 3", "K = 4", "K = 5", "ĐCXTB (%)"]
    N_arr = ["N_MFCC = 13"]
    accuracy_percent_synthesis[0, 0] = ""
    accuracy_percent_synthesis[1:, 0] = N_arr
    accuracy_percent_synthesis[0, 1:] = K_arr
    idx = 0
    for K in range(2, 6): # K chạy từ 2 -> 5
        kmean_mfcc_feature_vectors = find_kmean_vectors(frame_length, frame_shift, Fs, K) # Tìm 5 * K vector đặc trưng
        
        statictics_table, confusion_matrix, time_processing_vowels = recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs)
        idx += 1
        confusion_matrix, accuracy_percent_synthesis = accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx)
        # Tiến hành hiển thị vector đặc trưng
        title = f"Vector đặc trưng MFCC với N_MFCC = 13 và K = {K}"
        show_feature_mfcc_vectors(kmean_mfcc_feature_vectors, K, title)
        # In ra bảng thống kê
        title = f"Kết quả nhận dạng với N_MFCC = 13 và K = {K}"
        show_statictics_table(statictics_table, title)
        title = f"Ma trận nhầm lẫn với N_MFCC = 13 và K = {K}"
        show_confusion_matrix(confusion_matrix, title, time_processing_vowels)
        title = f"Độ chính xác nhận dạng tổng hợp theo số cụm K"
    show_accuracy_matrix(accuracy_percent_synthesis, title)

# %%
if __name__ == "__main__":
    Bai3()
# Out:
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.02400517463684082
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.045398712158203125
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.03200030326843262
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.041188955307006836
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.03300642967224121
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.03601336479187012
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.031002283096313477
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.02900862693786621
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.030023813247680664
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.021004915237426758
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.027005672454833984
#
# Consuming time for a in NguyenAmKiemThu-16k\12FTD\a.wav: 0.03000664710998535
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.040995121002197266
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.035004377365112305
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.03802371025085449
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.03400564193725586
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.036012887954711914
#
# Consuming time for a in NguyenAmKiemThu-16k\19MXK\a.wav: 0.03900861740112305
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.022000551223754883
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.02400994300842285
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.023990154266357422
#
# label: NguyenAmKiemThu-16k\22MHL\a
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.02402186393737793
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\e.wav: 0.047011375427246094
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.030987024307250977
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.035025835037231445
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.032007455825805664
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.038306474685668945
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.03502464294433594
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.029986858367919922
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.030010461807250977
#
# Consuming time for e in NguyenAmKiemThu-16k\10MSD\e.wav: 0.025002002716064453
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.030007362365722656
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.03300738334655762
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\e.wav: 0.04302525520324707
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.03801250457763672
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.034990549087524414
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\e.wav: 0.030003786087036133
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.03702878952026367
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.03800821304321289
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.02199101448059082
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.020018577575683594
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.025005578994750977
#
# label: NguyenAmKiemThu-16k\22MHL\e
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.020987510681152344
#
# Consuming time for i in NguyenAmKiemThu-16k\02FVA\i.wav: 0.04002237319946289
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.031992435455322266
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.034008026123046875
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.03400731086730957
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.03400731086730957
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.030025720596313477
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.028987884521484375
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.030009031295776367
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.023016929626464844
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.02701091766357422
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.03300738334655762
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.037992000579833984
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.03800702095031738
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.03002476692199707
#
# Consuming time for i in NguyenAmKiemThu-16k\17MTH\i.wav: 0.028989553451538086
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.03902626037597656
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.035006046295166016
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.02598881721496582
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.02504754066467285
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.023989200592041016
#
# label: NguyenAmKiemThu-16k\22MHL\i
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.024021148681640625
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.03700828552246094
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.033002614974975586
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.034012556076049805
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.03819990158081055
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.034018754959106445
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\o.wav: 0.020008087158203125
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.026006698608398438
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.028006315231323242
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.027132749557495117
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.03186297416687012
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.04100918769836426
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.03702569007873535
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.03498721122741699
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.03302741050720215
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.03100419044494629
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.040021419525146484
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.03599143028259277
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.025025367736816406
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.025005340576171875
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.024005889892578125
#
# label: NguyenAmKiemThu-16k\22MHL\o
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.021999835968017578
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.03501296043395996
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.06600022315979004
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.031003713607788086
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\u.wav: 0.035005807876586914
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.031010150909423828
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.028003454208374023
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.025025129318237305
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.02600574493408203
#
# Consuming time for u in NguyenAmKiemThu-16k\10MSD\u.wav: 0.025000810623168945
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.02701091766357422
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.03399062156677246
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.031023740768432617
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.03200721740722656
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.0309906005859375
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.03200364112854004
#
# Consuming time for u in NguyenAmKiemThu-16k\18MNK\u.wav: 0.03702855110168457
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.03500771522521973
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.025005578994750977
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.021004915237426758
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.0200045108795166
#
# label: NguyenAmKiemThu-16k\22MHL\u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03203409058707101}, {'vowel': 'e', 'avg_time': 0.032308714730398994}, {'vowel': 'i', 'avg_time': 0.031007335299537295}, {'vowel': 'o', 'avg_time': 0.03144682021368118}, {'vowel': 'u', 'avg_time': 0.030911706742786225}]
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.028005361557006836
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.040007829666137695
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.038008928298950195
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.03300833702087402
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.03202629089355469
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.03899383544921875
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.031017303466796875
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.030995845794677734
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.03201889991760254
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.021008729934692383
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.028990745544433594
#
# Consuming time for a in NguyenAmKiemThu-16k\12FTD\a.wav: 0.0290224552154541
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.041008949279785156
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.03600430488586426
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.03701210021972656
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.03300762176513672
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.037008047103881836
#
# Consuming time for a in NguyenAmKiemThu-16k\19MXK\a.wav: 0.03900885581970215
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.021004915237426758
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.02700638771057129
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.025005102157592773
#
# label: NguyenAmKiemThu-16k\22MHL\a
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.028987407684326172
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\e.wav: 0.04002809524536133
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.028991222381591797
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\e.wav: 0.03600478172302246
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.03502488136291504
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.04099464416503906
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.037024497985839844
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.0290067195892334
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.026992321014404297
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\e.wav: 0.023019075393676758
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.030002832412719727
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.03201150894165039
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.04338216781616211
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.039017677307128906
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.034032583236694336
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\e.wav: 0.02801036834716797
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.03500771522521973
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.04298996925354004
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.027010202407836914
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.024000883102416992
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.02902674674987793
#
# label: NguyenAmKiemThu-16k\22MHL\e
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.021986007690429688
#
# Consuming time for i in NguyenAmKiemThu-16k\02FVA\i.wav: 0.04101681709289551
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.03200864791870117
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.03500556945800781
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.03600811958312988
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.04501152038574219
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.02900552749633789
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.03202390670776367
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.029987335205078125
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.02901005744934082
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.032006263732910156
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.0420074462890625
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.04001474380493164
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.03900408744812012
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.02902364730834961
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\i.wav: 0.029009342193603516
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.03700542449951172
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.037989139556884766
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.02802562713623047
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.025005817413330078
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.028003692626953125
#
# label: NguyenAmKiemThu-16k\22MHL\i
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.027991056442260742
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.04503273963928223
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.04399824142456055
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.04001212120056152
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.03800821304321289
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.037007808685302734
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\o.wav: 0.021004438400268555
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.026006698608398438
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.02800607681274414
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.030028104782104492
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.03899025917053223
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.04100751876831055
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.03902721405029297
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.03500843048095703
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.03399252891540527
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.0290219783782959
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.036992549896240234
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.04200553894042969
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.025006532669067383
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.025023460388183594
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.024988651275634766
#
# label: NguyenAmKiemThu-16k\22MHL\o
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.02100968360900879
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.03598737716674805
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.06703495979309082
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.03200721740722656
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\u.wav: 0.03200721740722656
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.03317141532897949
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.02898693084716797
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.025005817413330078
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.028006553649902344
#
# Consuming time for u in NguyenAmKiemThu-16k\10MSD\u.wav: 0.025469303131103516
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.02800750732421875
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.033025264739990234
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.032007455825805664
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.03199458122253418
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.030014753341674805
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.032012939453125
#
# Consuming time for u in NguyenAmKiemThu-16k\18MNK\u.wav: 0.03600716590881348
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.0349881649017334
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.028020858764648438
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.021003007888793945
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.020989179611206055
#
# label: NguyenAmKiemThu-16k\22MHL\u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03234146890186128}, {'vowel': 'e', 'avg_time': 0.032884109587896435}, {'vowel': 'i', 'avg_time': 0.03324565433320545}, {'vowel': 'o', 'avg_time': 0.033721912474859325}, {'vowel': 'u', 'avg_time': 0.03127415974934896}]
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.02300548553466797
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.04004263877868652
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.03701043128967285
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.03302168846130371
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.03300642967224121
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.034998178482055664
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.031004667282104492
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.031020164489746094
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.031004905700683594
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.023020505905151367
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.0290067195892334
#
# Consuming time for e in NguyenAmKiemThu-16k\12FTD\a.wav: 0.03300762176513672
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.04100918769836426
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.035007476806640625
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.03400778770446777
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.03399038314819336
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.03700757026672363
#
# Consuming time for a in NguyenAmKiemThu-16k\19MXK\a.wav: 0.04001021385192871
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.02100372314453125
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.025004148483276367
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.02300548553466797
#
# label: NguyenAmKiemThu-16k\22MHL\a
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.024019479751586914
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\e.wav: 0.0430142879486084
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.031007051467895508
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.03400754928588867
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.03500795364379883
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.04041481018066406
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.03503155708312988
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.031991004943847656
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.029024600982666016
#
# Consuming time for e in NguyenAmKiemThu-16k\10MSD\e.wav: 0.02301931381225586
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.02900218963623047
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.03301286697387695
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.04100823402404785
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.04010272026062012
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.0329136848449707
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\e.wav: 0.030006885528564453
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.04600644111633301
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.04901480674743652
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.021004915237426758
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.02298736572265625
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.03000473976135254
#
# label: NguyenAmKiemThu-16k\22MHL\e
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.024025440216064453
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\i.wav: 0.040993690490722656
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.035002946853637695
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.04000973701477051
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.03602743148803711
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.03798842430114746
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.03102731704711914
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.03198719024658203
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.03300786018371582
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.027007341384887695
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.027003765106201172
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.03600931167602539
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.04202866554260254
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.04299354553222656
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.035006046295166016
#
# Consuming time for i in NguyenAmKiemThu-16k\17MTH\i.wav: 0.03424549102783203
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.04001140594482422
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.04101061820983887
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.027003049850463867
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.026007413864135742
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.026003360748291016
#
# label: NguyenAmKiemThu-16k\22MHL\i
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.030026674270629883
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.04298973083496094
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.034008026123046875
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.037027597427368164
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.03799009323120117
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.040022850036621094
#
# Consuming time for o in NguyenAmKiemThu-16k\07FTC\o.wav: 0.022009849548339844
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.03200268745422363
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.0309906005859375
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.026005268096923828
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.030004024505615234
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.038011789321899414
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.03900504112243652
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.0380091667175293
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.042012929916381836
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.03200888633728027
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.03800606727600098
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.0420069694519043
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.027005910873413086
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.026006221771240234
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.025005817413330078
#
# label: NguyenAmKiemThu-16k\22MHL\o
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.02500605583190918
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.04100680351257324
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.06601476669311523
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.03200674057006836
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\u.wav: 0.034008026123046875
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.03301119804382324
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.03500533103942871
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.027003765106201172
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.030006885528564453
#
# Consuming time for u in NguyenAmKiemThu-16k\10MSD\u.wav: 0.029014110565185547
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.025005817413330078
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.033026695251464844
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.03300738334655762
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.03600811958312988
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.031007051467895508
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.03198957443237305
#
# Consuming time for u in NguyenAmKiemThu-16k\18MNK\u.wav: 0.037008047103881836
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.03300642967224121
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.02500772476196289
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.024004697799682617
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.024003982543945312
#
# label: NguyenAmKiemThu-16k\22MHL\u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.031866448266165595}, {'vowel': 'e', 'avg_time': 0.03340964090256464}, {'vowel': 'i', 'avg_time': 0.03401905014401391}, {'vowel': 'o', 'avg_time': 0.03381696201506115}, {'vowel': 'u', 'avg_time': 0.03262662887573242}]
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\2284769709.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.02600550651550293
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.03900790214538574
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.039015769958496094
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.03500509262084961
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.03300786018371582
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.03600668907165527
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.030009984970092773
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.029005765914916992
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.031022310256958008
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.021004438400268555
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.027005672454833984
#
# Consuming time for e in NguyenAmKiemThu-16k\12FTD\a.wav: 0.029992341995239258
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.041023969650268555
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.03800535202026367
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.03801155090332031
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.03300762176513672
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.03600811958312988
#
# Consuming time for a in NguyenAmKiemThu-16k\19MXK\a.wav: 0.0400087833404541
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.02200031280517578
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.024010419845581055
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.02798771858215332
#
# label: NguyenAmKiemThu-16k\22MHL\a
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.027940750122070312
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\e.wav: 0.03929877281188965
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.024098873138427734
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.036603450775146484
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.03126263618469238
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.03943943977355957
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.03763389587402344
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.024173259735107422
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.03248143196105957
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\e.wav: 0.01628589630126953
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.023149490356445312
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.0468904972076416
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.03665447235107422
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.04334378242492676
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.041219472885131836
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\e.wav: 0.037078857421875
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.03934597969055176
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.03306913375854492
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.02386951446533203
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.023867368698120117
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.0241391658782959
#
# label: NguyenAmKiemThu-16k\22MHL\e
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.02710890769958496
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\i.wav: 0.03425288200378418
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.03323817253112793
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.041312456130981445
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.025524139404296875
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.03331112861633301
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.04229378700256348
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.024583816528320312
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.03859400749206543
#
# Consuming time for u in NguyenAmKiemThu-16k\10MSD\i.wav: 0.015906333923339844
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.02826380729675293
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.03231334686279297
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.03796529769897461
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.04576230049133301
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.03382587432861328
#
# Consuming time for i in NguyenAmKiemThu-16k\17MTH\i.wav: 0.024158477783203125
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.03809094429016113
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.04790973663330078
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\i.wav: 0.02939915657043457
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.026192903518676758
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.024544477462768555
#
# label: NguyenAmKiemThu-16k\22MHL\i
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.02558612823486328
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.03379082679748535
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.03681755065917969
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.035321712493896484
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.03980898857116699
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.037247419357299805
#
# Consuming time for o in NguyenAmKiemThu-16k\07FTC\o.wav: 0.029074430465698242
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.028795719146728516
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.025278806686401367
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.018094301223754883
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\o.wav: 0.039504289627075195
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.03791046142578125
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.03128194808959961
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.040071964263916016
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.04395294189453125
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.03128218650817871
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.04183244705200195
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.03428792953491211
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.016637086868286133
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.04180312156677246
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.026001453399658203
#
# label: NguyenAmKiemThu-16k\22MHL\o
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.021008968353271484
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.03500795364379883
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.06200909614562988
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.03899955749511719
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\u.wav: 0.03900504112243652
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.042012691497802734
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.03202176094055176
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.02600574493408203
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.027006149291992188
#
# Consuming time for u in NguyenAmKiemThu-16k\10MSD\u.wav: 0.028023958206176758
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.024988412857055664
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.03500986099243164
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.03500676155090332
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.030025959014892578
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.031009912490844727
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.03200531005859375
#
# Consuming time for u in NguyenAmKiemThu-16k\18MNK\u.wav: 0.03700733184814453
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.0350034236907959
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.027010679244995117
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.02100682258605957
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.021989822387695312
#
# label: NguyenAmKiemThu-16k\22MHL\u
# time consuming vowel: [{'vowel': 'a', 'avg_time': 0.03219777061825707}, {'vowel': 'e', 'avg_time': 0.032468863895961216}, {'vowel': 'i', 'avg_time': 0.032597712108067105}, {'vowel': 'o', 'avg_time': 0.0330657958984375}, {'vowel': 'u', 'avg_time': 0.0324364389692034}]
