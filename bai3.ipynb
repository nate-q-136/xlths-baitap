# %%
import numpy as np
import scipy.signal
from scipy.io import wavfile
import scipy.io.wavfile
import librosa
import matplotlib.pyplot as plt
import os
from pandas import DataFrame
import time
from scipy.signal.windows import hamming
from sklearn.cluster import KMeans

# %%
# Lấy list wav files từ 1 folder
def get_wav_files(folder_path):
    wav_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".wav"):
                wav_files.append(os.path.join(root, file))
    return wav_files

base_audio_train_folder = "NguyenAmHuanLuyen-16k"
audio_train_folders = [os.path.join(base_audio_train_folder, folder) for folder in os.listdir(base_audio_train_folder)]
audio_train_file_paths = []
for folder in audio_train_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_train_file_paths.append(item)

base_audio_test_folder = "NguyenAmKiemThu-16k"
audio_test_folders = [os.path.join(base_audio_test_folder, folder) for folder in os.listdir(base_audio_test_folder)]
audio_test_file_paths = []
for folder in audio_test_folders:
    folder_name = os.path.basename(folder)
    item = {
        'folder_name': folder_name,
        'audio_files': get_wav_files(folder)
    }
    audio_test_file_paths.append(item)

# %%
def find_vowel_files(audio_file_paths, vowel_file):
    vowel_files_in_paths = []
    for item in audio_file_paths:
        # Tìm các file trong list tương ứng của từng folder
        matching_files = [f for f in item['audio_files'] if os.path.basename(f) in vowel_file]
        if matching_files:
            vowel_files_in_paths.extend(matching_files)
    return vowel_files_in_paths

# %%
def format_accuracy_matrix(matrix):
    formatted_matrix = matrix.copy()
    for i in range(1, matrix.shape[0]):
        for j in range(1, matrix.shape[1]):
            # Chỉ format các ô không phải tiêu đề (giả định đây là số hoặc None)
            if matrix[i, j] is not None:
                formatted_matrix[i, j] = f"{matrix[i, j]:.1f}"
    return formatted_matrix

# %%
def show_accuracy_matrix(accuracy_percent_synthesis, title):
    formatted = format_accuracy_matrix(accuracy_percent_synthesis)
    fig, ax = plt.subplots(figsize=(8, 3))  # Modify the size as needed
    ax.set_title(title, color='blue', loc='center',fontweight='bold')
    ax.axis('off')
    ax.axis('tight')
    table = ax.table(cellText=formatted, loc='center', cellLoc='center', edges='closed')
    table.auto_set_column_width(col=list(range(len(formatted[0]))))  
    table.auto_set_font_size(False)  
    table.set_fontsize(11)  
    fig.tight_layout()
    plt.show()

# %%
def show_statictics_table(statictics_table, title):
    # Vẽ bảng thống kê
    fig, ax = plt.subplots()
    ax.set_title(title)
    ax.axis('off')
    ax.axis('tight')
    ax.table(cellText=statictics_table, loc='center')
    fig.tight_layout()
    plt.show()

# %%
def show_feature_mfcc_vectors(feature_vectors, K, title1):
    N_MFCC = 13
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    n = np.arange(N_MFCC)
    plt.figure(figsize=(20,10))
    plt.title(title1)
    plt.plot(n, feature_vectors[0, :], 'b', label=vowel_files[0])
    plt.plot(n, feature_vectors[K, :], 'y', label=vowel_files[1])
    plt.plot(n, feature_vectors[2 * K, :], 'darkcyan', label=vowel_files[2])
    plt.plot(n, feature_vectors[3 * K, :], 'orange', label=vowel_files[3])
    plt.plot(n, feature_vectors[4 * K, :], 'r', label=vowel_files[4])
    plt.legend()
    plt.xlabel('Chỉ số')
    plt.ylabel('Hệ số MFCC')
    plt.show()
    plt.figure()

# %%
def show_confusion_matrix(confusion_matrix, title):
    for row in confusion_matrix[1:]:
        if type(row[-1]) == float:  
            row[-1] = "{:.1f}".format(row[-1])
        else:
            row[-1] = ""  
    df_cm = DataFrame(
        [row[1:] for row in confusion_matrix[1:]], 
        columns=confusion_matrix[0][1:],  
        index=[row[0] for row in confusion_matrix[1:]]  
    )
    fig, ax = plt.subplots(figsize=(14, 5))  
    ax.set_title(title, color='blue', loc='center', fontweight='bold')
    ax.axis('off')  
    tab = ax.table(cellText=df_cm.values, cellLoc='center', loc='center', rowLabels=df_cm.index, colLabels=df_cm.columns)
    tab.auto_set_font_size(False)
    tab.set_fontsize(14)
    tab.scale(1, 1.4)
    max_index = df_cm.iloc[:-1, -1].astype(float).idxmax()  # Tìm percent cao nhất
    min_index = df_cm.iloc[:-1, -1].astype(float).idxmin()  # Tìm percent thấp nhất


    for key, cell in tab.get_celld().items():
        if key[0] == 0:
            cell.set_text_props(color='black', fontweight='bold')
            cell.set_facecolor('lightgrey')
            
    for (i, row) in enumerate(df_cm.iterrows(), start=1):
        if row[0] == max_index :  # Highlight dòng có percent cao nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j)].set_facecolor('lightgreen')
        if row[0] == min_index:   # Highlight dòng có percent thấp nhất
            for j in range(len(df_cm.columns)):
                tab[(i, j)].set_facecolor('salmon')
    plt.show()

# %%
def show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime):
    plt.figure()
    plt.plot(np.arange(0, len(data) * T, T), data) # tín hiệu sau khi chuẩn hóa
    plt.title("Speech and Stable Area of the Signal ")
    # Vẽ vùng tiếng nói
    plt.axvline(x=(speech_area[0]) * sample_shift_frame * T, color='r', linestyle='--', label="Start of Speech")
    plt.axvline(x=(speech_area[-1]) * sample_shift_frame * T, color='r', linestyle='--', label="End of Speech")
    # Vẽ vùng ổn định
    plt.axvline(x=(startTime) * sample_shift_frame * T, color='b', linestyle='--', label="Start of Stable Speech")
    plt.axvline(x=(endTime) * sample_shift_frame * T, color='b', linestyle='--', label="End of Stable Speech")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Khoảng cách Euclidean giữa 2 vector
def euclideanDistance(v1, v2):
    return np.linalg.norm(v1 - v2)

# %%
def accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx):
    total_percent = 0
    for i in range(5):
        total_correct = confusion_matrix[i + 1][i + 1] # Số lần nhận dạng đúng
        confusion_matrix[i + 1][6] = f"{total_correct}/21" 
        percent = float(total_correct) / 21 * 100 # Phần trăm nhận dạng đúng
        confusion_matrix[i + 1][7] = percent
        total_percent += percent
    confusion_matrix[6][7] = total_percent / 5
    accuracy_percent_synthesis[1][idx] = total_percent / 5 # Độ chính xác trung bình
    total_percent = 0
    if (idx == 4):
        for i in range(4):
            total_percent += accuracy_percent_synthesis[1][i + 1]
        accuracy_percent_synthesis[1][idx + 1] = total_percent / 4 # Độ chính xác trung bình của tất cả các K
    return confusion_matrix, accuracy_percent_synthesis

# %%
def find_speech_area(files, frame_length, frame_shift):
    sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
    T = 1 / sampleRate # Chu kỳ
    # 1s -> 16K sample
    sample_one_frame = round(frame_length * sampleRate) # số mẫu 1 khung
    sample_shift_frame = round(frame_shift * sampleRate) # số mẫu khoảng dịch
    # Tổng số khung thu được = (số lượng mẫu - số mẫu 1 khung) // số mẫu khoảng dịch + 1
    total_number_frame = (len(data) - sample_one_frame) // sample_shift_frame + 1
    # Chuẩn hóa data về biên độ [-1, 1]
    data = data / abs(max(data))
    # Chia data thành các frame
    list_frames = [data[i * sample_shift_frame : i * sample_shift_frame + sample_one_frame] for i in range(total_number_frame)]
    list_frames = np.array(list_frames)
    ste_frame = np.sum(list_frames ** 2, axis=1) # STE từng frame
    ste_frame /= max(ste_frame) # Chuẩn hóa STE
    threshold = 0.01 # Ngưỡng thủ công
    speech_area = np.where(ste_frame >= threshold)[0] # tìm vùng tiếng nói
    return list_frames, data, T, sample_shift_frame, speech_area

# %%
def find_stable_area(files, frame_length, frame_shift): # tìm vùng ổn định
    list_frames, data, T, sample_shift_frame, speech_area = find_speech_area(files, frame_length, frame_shift)
    dist = int(np.ceil((speech_area[-1] - speech_area[0]) / 3)) # Chia thành 3 đoạn bằng nhau
    startTime = speech_area[0] + dist # Vị trí bắt đầu vùng ổn định
    endTime = speech_area[0] + 2 * dist # Vị trí kết thúc vùng ổn định
    return list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area

# %%
def find_vowel_feature_mfcc_vectors(list_frames, timeStart, timeEnd, N_MFCC, Fs, frame_length, frame_shift):
    coef_mfcc_vectors = []
    frame_length_sample = round(frame_length * Fs)   # Độ dài khung (frame length) chuyển đổi sang mẫu
    hop_length_sample = round(frame_shift * Fs)     # Khoảng dịch khung (frame step) chuyển đổi sang mẫu
    for k in range(timeStart, timeEnd + 1): 
        coef_mfcc_vector = librosa.feature.mfcc(y=list_frames[k, :], sr=16000, n_mfcc=N_MFCC+1, n_fft=frame_length_sample, hop_length=hop_length_sample, 
                                        window='hamming')[1:,]  
        coef_mfcc_vectors.append(coef_mfcc_vector.mean(axis=1))  
    return np.array(coef_mfcc_vectors)

# %%
def recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs):
    N_MFCC = 13
    folder_names = [item['folder_name'] for item in audio_test_file_paths]
    vowel_files = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] 
    vowels = ["a", "e", "i", "o", "u"]
    num_folders = len(folder_names)
    num_files = len(vowel_files)
    statictics_table = np.zeros((num_folders + 1, num_files + 1), dtype=object)
    statictics_table[0, 0] = ""
    statictics_table[1:, 0] = folder_names
    statictics_table[0, 1:] = vowel_files
    confusion_matrix = [
        ["", "a", "e", "i", "o", "u", "Tỉ lệ", "ĐCX (%)"],
        ["  a  ", 0, 0, 0, 0, 0, 0, 0],
        ["  e  ", 0, 0, 0, 0, 0, 0, 0],
        ["  i  ", 0, 0, 0, 0, 0, 0, 0],
        ["  o  ", 0, 0, 0, 0, 0, 0, 0],
        ["  u  ", 0, 0, 0, 0, 0, 0, 0],
        ["     ", "", "", "", "", "", "", 0]
    ]
    for i in range(num_files):
        vowel_files_in_paths = find_vowel_files(audio_test_file_paths, vowel_files[i])
        j = -1
        for file in vowel_files_in_paths:
            start_time = time.time()

            j += 1
            # Tìm vùng ổn định
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(file, frame_length, frame_shift)
            # Tìm vector đặc trưng MFCC
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            # Tìm khoảng cách ngắn nhất
            min_dist = euclideanDistance(kmean_mfcc_feature_vectors[0, :], vowel_feature_mfcc_vector)
            index = 0
            for k in range(1, 5 * K): 
                min_t = euclideanDistance(kmean_mfcc_feature_vectors[k, :], vowel_feature_mfcc_vector)
                if min_t < min_dist:
                    min_dist = min_t
                    index = k
            index = index // K            
            # Điền vào bảng
            statictics_table[j + 1, i + 1] = vowels[index]
            confusion_matrix[i + 1][index + 1] += 1

            end_time = time.time()
            print(f"Consuming time for {vowels[index]} in {file}: {end_time - start_time}\n")
    return statictics_table, confusion_matrix

# %%
def find_kmean_vectors(frame_length, frame_shift, Fs, K):
    N_MFCC = 13 # Số lượng hệ số MFCC
    kmean_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC khi áp dụng Kmean
    vowel_file = ["a.wav", "e.wav", "i.wav", "o.wav", "u.wav"] # file nguyên âm
    for i in range(len(vowel_file)): # Chạy từng nguyên âm
        vowel_files_in_paths = find_vowel_files(audio_train_file_paths, vowel_file[i]) # Lấy đường dẫn có vowel_file
        vowel_feature_mfcc_vectors = np.zeros((0, N_MFCC)) # vector đặc trưng MFCC của 1 nguyên âm nhiều người nói
        for files in vowel_files_in_paths: # Duyệt từng file 
            list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area(files, frame_length, frame_shift) # Tìm vùng ổn định
            # Tìm vector đặc trưng MFCC 1 nguyên âm 1 người nói
            vowel_feature_mfcc_vector = find_vowel_feature_mfcc_vectors(list_frames, startTime, endTime, N_MFCC, Fs, frame_length, frame_shift)
            vowel_feature_mfcc_vectors = np.vstack((vowel_feature_mfcc_vectors, vowel_feature_mfcc_vector))
        # Tiến hành chia cụm
        kmeans = KMeans(n_clusters=K, random_state=0).fit(vowel_feature_mfcc_vectors)
        centroids = kmeans.cluster_centers_ # Tìm trung tâm cụm
        kmean_feature_mfcc_vectors = np.vstack((kmean_feature_mfcc_vectors, centroids))
    return kmean_feature_mfcc_vectors # 5 * K vector kmean

# %%
def Bai3():
    frame_length = 0.02 # Độ dài khung
    frame_shift = 0.01 # Độ dịch khung
    Fs = 16000
    # Vẽ 1 tín hiệu từ file để kiểm tra vùng ổn định
    list_frames, startTime, endTime, data, T, sample_shift_frame, speech_area = find_stable_area("NguyenAmHuanLuyen-16k/23MTL/i.wav", frame_length, frame_shift)
    show_speech_stable(data, T, speech_area, sample_shift_frame, startTime, endTime)
    accuracy_percent_synthesis = np.zeros((2, 6), dtype=object)
    K_arr = ["K = 2", "K = 3", "K = 4", "K = 5", "ĐCXTB (%)"]
    N_arr = ["N_MFCC = 13"]
    accuracy_percent_synthesis[0, 0] = ""
    accuracy_percent_synthesis[1:, 0] = N_arr
    accuracy_percent_synthesis[0, 1:] = K_arr
    idx = 0
    for K in range(2, 6): # K chạy từ 2 -> 5
        kmean_mfcc_feature_vectors = find_kmean_vectors(frame_length, frame_shift, Fs, K) # Tìm 5 * K vector đặc trưng
        
        statictics_table, confusion_matrix = recognition(frame_length, frame_shift, kmean_mfcc_feature_vectors, K, Fs)
        idx += 1
        confusion_matrix, accuracy_percent_synthesis = accuracy_percent_recognition(confusion_matrix, accuracy_percent_synthesis, idx)
        # Tiến hành hiển thị vector đặc trưng
        title = f"Vector đặc trưng MFCC với N_MFCC = 13 và K = {K}"
        show_feature_mfcc_vectors(kmean_mfcc_feature_vectors, K, title)
        # In ra bảng thống kê
        title = f"Kết quả nhận dạng với N_MFCC = 13 và K = {K}"
        show_statictics_table(statictics_table, title)
        title = f"Ma trận nhầm lẫn với N_MFCC = 13 và K = {K}"
        show_confusion_matrix(confusion_matrix, title)
        title = f"Độ chính xác nhận dạng tổng hợp theo số cụm K"
    show_accuracy_matrix(accuracy_percent_synthesis, title)

# %%
if __name__ == "__main__":
    Bai3()
# Out:
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.04100918769836426
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.05701327323913574
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.04703164100646973
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.04899311065673828
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.06002926826477051
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.04901123046875
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.039991140365600586
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.04901003837585449
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.046024322509765625
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.05601978302001953
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.04600787162780762
#
# Consuming time for a in NguyenAmKiemThu-16k\12FTD\a.wav: 0.062018632888793945
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.06701207160949707
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.06001019477844238
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.059995174407958984
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.04802703857421875
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.05399727821350098
#
# Consuming time for a in NguyenAmKiemThu-16k\19MXK\a.wav: 0.08003401756286621
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.037995100021362305
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.031023263931274414
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.03299212455749512
#
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.0380094051361084
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\e.wav: 0.06502676010131836
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.05201220512390137
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.05801677703857422
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.04801058769226074
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.06801795959472656
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.051011085510253906
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.04600381851196289
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.04099726676940918
#
# Consuming time for e in NguyenAmKiemThu-16k\10MSD\e.wav: 0.0380096435546875
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.05100846290588379
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.05901384353637695
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.06101274490356445
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.05407071113586426
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.041968345642089844
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\e.wav: 0.04947328567504883
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.05301260948181152
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.06344223022460938
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.036891937255859375
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.03505563735961914
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.03200364112854004
#
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.03200387954711914
#
# Consuming time for i in NguyenAmKiemThu-16k\02FVA\i.wav: 0.06813573837280273
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.048723697662353516
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.04800844192504883
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.048002004623413086
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.047989845275878906
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.06400632858276367
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.10035467147827148
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.038429975509643555
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.05344533920288086
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.04280829429626465
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.04958033561706543
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\i.wav: 0.0532994270324707
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.04479098320007324
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.04730343818664551
#
# Consuming time for i in NguyenAmKiemThu-16k\17MTH\i.wav: 0.04558753967285156
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.06198310852050781
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.05047488212585449
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.03124856948852539
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.04060673713684082
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.03127121925354004
#
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.04312539100646973
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.0571897029876709
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.031252384185791016
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.059797048568725586
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.05982637405395508
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.05056929588317871
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\o.wav: 0.03211855888366699
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.0435941219329834
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.03214120864868164
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.03152751922607422
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.03603363037109375
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.05642247200012207
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.04989814758300781
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.049527645111083984
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.04896283149719238
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.045906782150268555
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.05425739288330078
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.05886650085449219
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.032744646072387695
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.028427839279174805
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.041852474212646484
#
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.03339672088623047
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.03753209114074707
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.09291362762451172
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.05148911476135254
#
# Consuming time for u in NguyenAmKiemThu-16k\05MVB\u.wav: 0.03432059288024902
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.05576896667480469
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.030977725982666016
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.03579521179199219
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.04020404815673828
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\u.wav: 0.09192371368408203
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.031362056732177734
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.052433013916015625
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.047772884368896484
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.049283504486083984
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.0388035774230957
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.050293684005737305
#
# Consuming time for u in NguyenAmKiemThu-16k\18MNK\u.wav: 0.04568076133728027
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.04577064514160156
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.03257322311401367
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.024063587188720703
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.04277658462524414
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.03125166893005371
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.059307098388671875
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.039333343505859375
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.05095720291137695
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.07161474227905273
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.049442291259765625
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.04800724983215332
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.04811739921569824
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.04888105392456055
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.03596687316894531
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.04411053657531738
#
# Consuming time for a in NguyenAmKiemThu-16k\12FTD\a.wav: 0.057296037673950195
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.056670427322387695
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.05343794822692871
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.055968523025512695
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.04323101043701172
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.05249428749084473
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\a.wav: 0.06468820571899414
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.026036977767944336
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.031408071517944336
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.032991886138916016
#
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.029505014419555664
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\e.wav: 0.07224416732788086
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.04489779472351074
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.046173095703125
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.05409669876098633
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.051505088806152344
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.0502476692199707
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.03983807563781738
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.037146806716918945
#
# Consuming time for e in NguyenAmKiemThu-16k\10MSD\e.wav: 0.021589994430541992
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.04579806327819824
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.03987288475036621
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.06918621063232422
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.05641579627990723
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.040024757385253906
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\e.wav: 0.048128366470336914
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.04850435256958008
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.06272363662719727
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.03008890151977539
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.026971817016601562
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.031273841857910156
#
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.03631162643432617
#
# Consuming time for i in NguyenAmKiemThu-16k\02FVA\i.wav: 0.05534172058105469
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.04115581512451172
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.047197580337524414
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.04689598083496094
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.052434682846069336
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.03264427185058594
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.0897073745727539
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.03137850761413574
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.06271696090698242
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.02378535270690918
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.06545329093933105
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.05105876922607422
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.059719085693359375
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.04000353813171387
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\i.wav: 0.0400240421295166
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.06605029106140137
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.060894012451171875
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.026070594787597656
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.03243875503540039
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.04306960105895996
#
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.029029369354248047
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.05083608627319336
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.05101203918457031
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.049280405044555664
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.04751706123352051
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.052835941314697266
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\o.wav: 0.03211188316345215
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.04990839958190918
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.0352778434753418
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.030675649642944336
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.040335655212402344
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.05910944938659668
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.0562739372253418
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.05000734329223633
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.04701042175292969
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.043024301528930664
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.07202029228210449
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.06299734115600586
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.0330197811126709
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.03599429130554199
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.03600788116455078
#
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.03102564811706543
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.05101156234741211
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.09400177001953125
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.04602980613708496
#
# Consuming time for u in NguyenAmKiemThu-16k\05MVB\u.wav: 0.04300975799560547
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.043006181716918945
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.0379939079284668
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.03202509880065918
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.0400090217590332
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\u.wav: 0.09002208709716797
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.04400372505187988
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.05699968338012695
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.04901003837585449
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.05001235008239746
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.04202723503112793
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.04701042175292969
#
# Consuming time for u in NguyenAmKiemThu-16k\18MNK\u.wav: 0.058008432388305664
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.05699944496154785
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.03502607345581055
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.029989004135131836
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.0330202579498291
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.041860342025756836
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.05014801025390625
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.042272329330444336
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.03849029541015625
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.0611882209777832
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.04896044731140137
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.04020237922668457
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.051038503646850586
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.044820547103881836
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.03113555908203125
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.041461944580078125
#
# Consuming time for a in NguyenAmKiemThu-16k\12FTD\a.wav: 0.05183553695678711
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.06464409828186035
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.04609274864196777
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.05523347854614258
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.05212259292602539
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.05932164192199707
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\a.wav: 0.05823159217834473
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.03404951095581055
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.025649547576904297
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.03125286102294922
#
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.04745888710021973
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\e.wav: 0.05580711364746094
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.05243515968322754
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.06412363052368164
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.04801440238952637
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.0656585693359375
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.043024539947509766
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.0379948616027832
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.041017770767211914
#
# Consuming time for e in NguyenAmKiemThu-16k\10MSD\e.wav: 0.03201174736022949
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.0400090217590332
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.05101156234741211
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.06301403045654297
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.060013532638549805
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.04700636863708496
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\e.wav: 0.04401397705078125
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.05305600166320801
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.05497026443481445
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.03200531005859375
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.03300285339355469
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.03300809860229492
#
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.033006906509399414
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\i.wav: 0.058017730712890625
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.04499053955078125
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.05603218078613281
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.048010826110839844
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.05001115798950195
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.038008689880371094
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.09100222587585449
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.040009498596191406
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.06799578666687012
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.03701019287109375
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.0560307502746582
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.061010122299194336
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.05701589584350586
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.042989492416381836
#
# Consuming time for i in NguyenAmKiemThu-16k\17MTH\i.wav: 0.0450131893157959
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.0710294246673584
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.061000823974609375
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.03200554847717285
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.04300856590270996
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.035027265548706055
#
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.0370326042175293
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.06201434135437012
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.04800605773925781
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.05801987648010254
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.059192657470703125
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.05502438545227051
#
# Consuming time for o in NguyenAmKiemThu-16k\07FTC\o.wav: 0.04699850082397461
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.03800654411315918
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.03900957107543945
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.03002452850341797
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.038008689880371094
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.058012962341308594
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.05599331855773926
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.047029972076416016
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.04601025581359863
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.042006731033325195
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.07001924514770508
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.053011178970336914
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.030002117156982422
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.0340123176574707
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.033007144927978516
#
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.02998971939086914
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.0470278263092041
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.08500361442565918
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.046025991439819336
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\u.wav: 0.04401063919067383
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.045005083084106445
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.039012908935546875
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.03300738334655762
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.038008928298950195
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\u.wav: 0.09600496292114258
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.04700875282287598
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.05703115463256836
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.049013614654541016
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.050028085708618164
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.04701066017150879
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.05599331855773926
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\u.wav: 0.05803275108337402
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.05401182174682617
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.032990455627441406
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.02900409698486328
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.031021595001220703
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# C:\Users\Quang Dong\AppData\Local\Temp\ipykernel_7668\567639455.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampleRate, data = wavfile.read(files) # Lấy tần số lấy mẫu, data của file
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Quang Dong\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# Consuming time for a in NguyenAmKiemThu-16k\01MDA\a.wav: 0.03901052474975586
#
# Consuming time for a in NguyenAmKiemThu-16k\02FVA\a.wav: 0.053009986877441406
#
# Consuming time for a in NguyenAmKiemThu-16k\03MAB\a.wav: 0.04301095008850098
#
# Consuming time for a in NguyenAmKiemThu-16k\04MHB\a.wav: 0.04702949523925781
#
# Consuming time for a in NguyenAmKiemThu-16k\05MVB\a.wav: 0.05499911308288574
#
# Consuming time for a in NguyenAmKiemThu-16k\06FTB\a.wav: 0.05200910568237305
#
# Consuming time for a in NguyenAmKiemThu-16k\07FTC\a.wav: 0.042026519775390625
#
# Consuming time for a in NguyenAmKiemThu-16k\08MLD\a.wav: 0.04700946807861328
#
# Consuming time for a in NguyenAmKiemThu-16k\09MPD\a.wav: 0.04399228096008301
#
# Consuming time for a in NguyenAmKiemThu-16k\10MSD\a.wav: 0.03602147102355957
#
# Consuming time for a in NguyenAmKiemThu-16k\11MVD\a.wav: 0.03601217269897461
#
# Consuming time for a in NguyenAmKiemThu-16k\12FTD\a.wav: 0.061997413635253906
#
# Consuming time for a in NguyenAmKiemThu-16k\14FHH\a.wav: 0.06102609634399414
#
# Consuming time for a in NguyenAmKiemThu-16k\15MMH\a.wav: 0.05500078201293945
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\a.wav: 0.05601048469543457
#
# Consuming time for a in NguyenAmKiemThu-16k\17MTH\a.wav: 0.04253435134887695
#
# Consuming time for a in NguyenAmKiemThu-16k\18MNK\a.wav: 0.06758809089660645
#
# Consuming time for a in NguyenAmKiemThu-16k\19MXK\a.wav: 0.07632756233215332
#
# Consuming time for a in NguyenAmKiemThu-16k\20MVK\a.wav: 0.030527353286743164
#
# Consuming time for a in NguyenAmKiemThu-16k\21MTL\a.wav: 0.03419208526611328
#
# Consuming time for a in NguyenAmKiemThu-16k\22MHL\a.wav: 0.04328513145446777
#
# Consuming time for e in NguyenAmKiemThu-16k\01MDA\e.wav: 0.038288116455078125
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\e.wav: 0.06162571907043457
#
# Consuming time for e in NguyenAmKiemThu-16k\03MAB\e.wav: 0.038591861724853516
#
# Consuming time for e in NguyenAmKiemThu-16k\04MHB\e.wav: 0.061495065689086914
#
# Consuming time for e in NguyenAmKiemThu-16k\05MVB\e.wav: 0.049004554748535156
#
# Consuming time for e in NguyenAmKiemThu-16k\06FTB\e.wav: 0.051444292068481445
#
# Consuming time for e in NguyenAmKiemThu-16k\07FTC\e.wav: 0.04732322692871094
#
# Consuming time for e in NguyenAmKiemThu-16k\08MLD\e.wav: 0.03707385063171387
#
# Consuming time for e in NguyenAmKiemThu-16k\09MPD\e.wav: 0.03991889953613281
#
# Consuming time for e in NguyenAmKiemThu-16k\10MSD\e.wav: 0.0312800407409668
#
# Consuming time for e in NguyenAmKiemThu-16k\11MVD\e.wav: 0.02930760383605957
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\e.wav: 0.06251192092895508
#
# Consuming time for e in NguyenAmKiemThu-16k\14FHH\e.wav: 0.05302786827087402
#
# Consuming time for e in NguyenAmKiemThu-16k\15MMH\e.wav: 0.05458331108093262
#
# Consuming time for e in NguyenAmKiemThu-16k\16FTH\e.wav: 0.04305148124694824
#
# Consuming time for e in NguyenAmKiemThu-16k\17MTH\e.wav: 0.0480191707611084
#
# Consuming time for e in NguyenAmKiemThu-16k\18MNK\e.wav: 0.05155372619628906
#
# Consuming time for e in NguyenAmKiemThu-16k\19MXK\e.wav: 0.06095409393310547
#
# Consuming time for e in NguyenAmKiemThu-16k\20MVK\e.wav: 0.028389930725097656
#
# Consuming time for e in NguyenAmKiemThu-16k\21MTL\e.wav: 0.03663229942321777
#
# Consuming time for e in NguyenAmKiemThu-16k\22MHL\e.wav: 0.038237571716308594
#
# Consuming time for i in NguyenAmKiemThu-16k\01MDA\i.wav: 0.022526264190673828
#
# Consuming time for e in NguyenAmKiemThu-16k\02FVA\i.wav: 0.06417655944824219
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\i.wav: 0.043609619140625
#
# Consuming time for i in NguyenAmKiemThu-16k\04MHB\i.wav: 0.039099931716918945
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\i.wav: 0.04689908027648926
#
# Consuming time for i in NguyenAmKiemThu-16k\06FTB\i.wav: 0.05185723304748535
#
# Consuming time for i in NguyenAmKiemThu-16k\07FTC\i.wav: 0.03125405311584473
#
# Consuming time for i in NguyenAmKiemThu-16k\08MLD\i.wav: 0.08619880676269531
#
# Consuming time for i in NguyenAmKiemThu-16k\09MPD\i.wav: 0.03986954689025879
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\i.wav: 0.06291723251342773
#
# Consuming time for i in NguyenAmKiemThu-16k\11MVD\i.wav: 0.031250715255737305
#
# Consuming time for i in NguyenAmKiemThu-16k\12FTD\i.wav: 0.05331230163574219
#
# Consuming time for i in NguyenAmKiemThu-16k\14FHH\i.wav: 0.06213688850402832
#
# Consuming time for i in NguyenAmKiemThu-16k\15MMH\i.wav: 0.04634737968444824
#
# Consuming time for i in NguyenAmKiemThu-16k\16FTH\i.wav: 0.04687952995300293
#
# Consuming time for i in NguyenAmKiemThu-16k\17MTH\i.wav: 0.0454866886138916
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\i.wav: 0.06501889228820801
#
# Consuming time for i in NguyenAmKiemThu-16k\19MXK\i.wav: 0.058012962341308594
#
# Consuming time for i in NguyenAmKiemThu-16k\20MVK\i.wav: 0.031007051467895508
#
# Consuming time for i in NguyenAmKiemThu-16k\21MTL\i.wav: 0.03700852394104004
#
# Consuming time for i in NguyenAmKiemThu-16k\22MHL\i.wav: 0.03399205207824707
#
# Consuming time for o in NguyenAmKiemThu-16k\01MDA\o.wav: 0.035007476806640625
#
# Consuming time for o in NguyenAmKiemThu-16k\02FVA\o.wav: 0.05401277542114258
#
# Consuming time for o in NguyenAmKiemThu-16k\03MAB\o.wav: 0.04601001739501953
#
# Consuming time for o in NguyenAmKiemThu-16k\04MHB\o.wav: 0.05002641677856445
#
# Consuming time for o in NguyenAmKiemThu-16k\05MVB\o.wav: 0.05501389503479004
#
# Consuming time for o in NguyenAmKiemThu-16k\06FTB\o.wav: 0.05100679397583008
#
# Consuming time for o in NguyenAmKiemThu-16k\07FTC\o.wav: 0.03701329231262207
#
# Consuming time for o in NguyenAmKiemThu-16k\08MLD\o.wav: 0.03999161720275879
#
# Consuming time for o in NguyenAmKiemThu-16k\09MPD\o.wav: 0.04102611541748047
#
# Consuming time for o in NguyenAmKiemThu-16k\10MSD\o.wav: 0.0309908390045166
#
# Consuming time for o in NguyenAmKiemThu-16k\11MVD\o.wav: 0.0380251407623291
#
# Consuming time for o in NguyenAmKiemThu-16k\12FTD\o.wav: 0.05599546432495117
#
# Consuming time for o in NguyenAmKiemThu-16k\14FHH\o.wav: 0.052025794982910156
#
# Consuming time for o in NguyenAmKiemThu-16k\15MMH\o.wav: 0.05301475524902344
#
# Consuming time for o in NguyenAmKiemThu-16k\16FTH\o.wav: 0.04500627517700195
#
# Consuming time for o in NguyenAmKiemThu-16k\17MTH\o.wav: 0.04100847244262695
#
# Consuming time for o in NguyenAmKiemThu-16k\18MNK\o.wav: 0.06603884696960449
#
# Consuming time for o in NguyenAmKiemThu-16k\19MXK\o.wav: 0.05599355697631836
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\o.wav: 0.03000640869140625
#
# Consuming time for o in NguyenAmKiemThu-16k\21MTL\o.wav: 0.03400778770446777
#
# Consuming time for o in NguyenAmKiemThu-16k\22MHL\o.wav: 0.03300738334655762
#
# Consuming time for u in NguyenAmKiemThu-16k\01MDA\u.wav: 0.029006481170654297
#
# Consuming time for u in NguyenAmKiemThu-16k\02FVA\u.wav: 0.05099344253540039
#
# Consuming time for i in NguyenAmKiemThu-16k\03MAB\u.wav: 0.08103442192077637
#
# Consuming time for u in NguyenAmKiemThu-16k\04MHB\u.wav: 0.04602932929992676
#
# Consuming time for i in NguyenAmKiemThu-16k\05MVB\u.wav: 0.04400992393493652
#
# Consuming time for u in NguyenAmKiemThu-16k\06FTB\u.wav: 0.04400634765625
#
# Consuming time for u in NguyenAmKiemThu-16k\07FTC\u.wav: 0.04199576377868652
#
# Consuming time for u in NguyenAmKiemThu-16k\08MLD\u.wav: 0.031025409698486328
#
# Consuming time for u in NguyenAmKiemThu-16k\09MPD\u.wav: 0.036003828048706055
#
# Consuming time for i in NguyenAmKiemThu-16k\10MSD\u.wav: 0.09000563621520996
#
# Consuming time for u in NguyenAmKiemThu-16k\11MVD\u.wav: 0.04002666473388672
#
# Consuming time for u in NguyenAmKiemThu-16k\12FTD\u.wav: 0.05101919174194336
#
# Consuming time for u in NguyenAmKiemThu-16k\14FHH\u.wav: 0.0440211296081543
#
# Consuming time for u in NguyenAmKiemThu-16k\15MMH\u.wav: 0.04701042175292969
#
# Consuming time for u in NguyenAmKiemThu-16k\16FTH\u.wav: 0.04299330711364746
#
# Consuming time for u in NguyenAmKiemThu-16k\17MTH\u.wav: 0.04502677917480469
#
# Consuming time for i in NguyenAmKiemThu-16k\18MNK\u.wav: 0.05548095703125
#
# Consuming time for u in NguyenAmKiemThu-16k\19MXK\u.wav: 0.04500937461853027
#
# Consuming time for u in NguyenAmKiemThu-16k\20MVK\u.wav: 0.03000664710998535
#
# Consuming time for u in NguyenAmKiemThu-16k\21MTL\u.wav: 0.02798938751220703
#
# Consuming time for u in NguyenAmKiemThu-16k\22MHL\u.wav: 0.030007362365722656
